# %%
import pandas as pd
import numpy as np
import random

np.random.seed(1)
random.seed(1)
TRAININFO = "/data/HitSongPrediction/train_info.tsv"
TRAINRANK =  "/data/HitSongPrediction/train_rank.csv"
TESTINFO = "/data/HitSongPrediction/test_info.tsv"
SUBMISSION = "/data/HitSongPrediction/submission.csv"

# Prepare data
df_i = pd.read_csv(TRAININFO, delimiter='\t',encoding='utf-8')
df_r = pd.read_csv(TRAINRANK)
df_i_train = df_i.merge(df_r, left_on='ID', right_on='ID')
df_i_train["dataset"] = "train"

df_i_test = pd.read_csv(TESTINFO, delimiter='\t',encoding='utf-8')
df_i_test["label"] = np.nan
df_i_test["dataset"] = "test"

df = pd.concat([df_i_train, df_i_test])
df_track_info = pd.read_csv("../../csv/all_track_info.csv")
df = df.merge(df_track_info, left_on='ID', right_on='ID')
df_audio_features = pd.read_csv("../../csv/all_track_audio_features.csv")
df =df.merge(df_audio_features,left_on="ID",right_on="ID", how="left")

# Sort by ID
df = df.sort_values(by=['ID'])
df= df.reset_index()

pd.set_option('display.max_rows', 3957)

df[["title", "album", "album_artist", "artist_name","genre", "composers_name", "track","release_time","length","label"]].head(1000)
# Out:
#                                                  title  \
# 0                               Đêm Chôn Dầu Vượt Biển
# 1                                    Mùa Thu Trong Mưa
# 2                                    Rồi Ánh Trăng Tan
# 3                       Còn Thương Rau Đắng Mọc Sau Hè
# 4                                  Người Điên Biết Yêu
# 5                                               Đàn Bà
# 6                     Yêu Một Người Sống Bên Một Người
# 7                                      Giấc Mơ Mình Em
# 8                                   Mất Nhau Trong Đời
# 9                                    Những Ân Tình Xưa
# 10                                    Ở Nơi Đó Em Cười
# 11                                      Tình Chấp Nhận
# 12                                  Rồi Mai Tôi Đưa Em
# 13                                 Thiên Đàng Đánh Mất
# 14                                             Vai Phụ
# 15                                   Tình Nhỏ Mau Quên
# 16                                      Rồi 30 Năm Qua
# 17                                   Chơi Vơi Dòng Đời
# 18                                 Dòng Sông Quê Hương
# 19                                    Hòa Bình Hoan Ca
# 20                                  Chúc Mừng Xuân Mới
# 21                                     Bên Đời Đã Vắng
# 22                                     Đã Xa Cuộc Tình
# 23                                    Chia Tay Ngày Hè
# 24                                       Khúc Mưa Buồn
# 25                             Xin Gọi Nhau Là Cố Nhân
# 26                                       Anh Thì Không
# 27                               Giọt Nước Mắt Cho Đời
# 28                                   Khúc Hát Yên Bình
# 29                                        Self Control
# 30                                              Ước Gì
# 31                                       Giữa Đôi Mình
# 32                                  Viễn Khúc Việt Nam
# 33                                             Hạ Buồn
# 34                                   Tiếng Hát Nửa Vời
# 35                                             Một Nhà
# 36                                 Cố Yêu Lại Càng Đau
# 37                                     Mong Gặp Lại Em
# 38                                              Ảo Ảnh
# 39                                     Thư Cho Vợ Hiền
# 40                                     Mùa Xuân Của Mẹ
# 41                                        Lời Nói Cuối
# 42                                       Miền Trung Ơi
# 43                                     Em Gái Miền Tây
# 44                                  Đau Lòng Lý Ngựa Ô
# 45                                   Mẹ Ơi Đời Nghệ Sĩ
# 20 Năm Tình Cũ                                         0       NaN        NaN
# 22                                                     1       NaN   4.000000
# 24H                                                    1       NaN   1.000000
# 26XX                                                   1       NaN   4.000000
# 27 Âm Lịch                                             1       NaN   1.000000
# 3 Phút                                                 1       NaN   1.000000
# 3 Đi (Đi. Đi. Đi)                                      1       NaN   1.000000
# 3 Đi (Đi. Đi. Đi) (TAD Sound Mix)                      1       NaN   1.000000
# 3T (Tôi Tồn Tại)                                       1       NaN   2.000000
# 3T (Tôi Tồn Tại) (G-House Version)                     1       NaN   1.000000
# 419                                                    1       NaN   1.000000
# 50% Khi Yêu                                            1       NaN   5.000000
# 54 Dân Tộc Anh Em                                      1       NaN   8.000000
# 54 Dân Tộc Anh Em (Beat)                               1       NaN   9.000000
# 5am                                                    1       NaN   1.000000
# 60 Năm Cuộc Đời (Cô Ba Sài Gòn OST)                    1       NaN   2.000000
# 60 Năm Cuộc Đời (Remix)                                1       NaN   2.000000
# 7 Ngày Đợi Mong                                        0       NaN        NaN
# 8 Dòng Yêu                                             1       NaN   8.000000
# 911106221                                              1       NaN   7.000000
# 999 Đóa Hồng                                           1       NaN   7.000000
# A Di Đà Phật                                           1       NaN   5.000000
# A Night Of Bar                                         1       NaN  10.000000
# A Night Of Bar (Beat)                                  1       NaN  10.000000
# A Sở Cô Nương                                          1       NaN   9.000000
# A Time For Us                                          1       NaN   7.000000
# A Ă Â                                                  1       NaN   3.000000
# A.V.N CYPHER                                           1       NaN   8.000000
# A.V.N SIGN UP                                          1       NaN   8.000000
# ARCSK                                                  0       NaN        NaN
# Ai Cho Tôi Tình Yêu                                    9  2.619372   6.111111
# Ai Cho Tôi Tình Yêu (New Version)                      1       NaN  10.000000
# Ai Cũng Hối Tiếc                                       0       NaN        NaN
# Ai Cũng Đẹp                                            1       NaN   8.000000
# Ai Hiểu Cho Riêng Mình ( Sơn Beat mix )                1       NaN   7.000000
# Ai Khâu Nước Mắt                                       1       NaN   3.000000
# Ai Khóc Ai Cười                                        1       NaN   7.000000
# Ai Khóc Nỗi Đau Này                                    1       NaN   1.000000
# Ai Khóc Nỗi Đau Này (Beat)                             1       NaN   1.000000
# Ai Khóc Nỗi Đau Này (Cover)                            1       NaN   2.000000
# Ai Khổ Vì Ai                                           8  2.434866   4.750000
# Ai Là Ai Của Ai                                        1       NaN   1.000000
# Ai Là Ai Của Ai (Beat Nam)                             1       NaN   3.000000
# Ai Là Ai Của Ai (Beat Nữ)                              1       NaN   3.000000
# Ai Là Người Sai                                        0       NaN        NaN
# Ai Lên Xứ Hoa Đào                                      2  0.000000   8.000000
# Ai Ngờ Ta Còn Thương                                   1       NaN   1.000000
# Ai Ngờ Ta Còn Thương (Glee Vietnam OST - Tập 14)       1       NaN   5.000000
# Ai Nhớ Chăng Ai                                        1       NaN   5.000000
# Ai Nói Ai Nghe                                         1       NaN   1.000000
# Ai Ra Xứ Huế                                           3  2.309401   8.666667
# Ai Sẽ Cần Tôi                                          1       NaN   6.000000
# Ai Sẽ Là Em                                            1       NaN   5.000000
# Ai Thương Yêu Em                                       1       NaN   3.000000
# Ai Yêu Anh Bằng Em                                     1       NaN   2.000000
# Ai Đã Cướp Nụ Hôn Của Anh                              1       NaN   1.000000
# Ai Đã Từng                                             1       NaN   1.000000
# Ai Đã Từng (Beat)                                      1       NaN   9.000000
# Ai Đó Cũng Đang Buồn                                   1       NaN   5.000000
# Ai Đó Từng Hứa (Beat)                                  1       NaN   5.000000
# Ai Đúng Ai Sai                                         1       NaN   3.000000
# Ai Đúng Ai Sai (Beat)                                  1       NaN   7.000000
# Ai Đưa Em Về                                           1       NaN   2.000000
# Ain’t Nobody Love You                                  1       NaN   2.000000
# Alibaba                                                1       NaN   5.000000
# All By Myself (Live)                                   1       NaN   7.000000
# All Of Me                                              1       NaN   3.000000
# Alright                                                1       NaN   8.000000
# Amen                                                   1       NaN   5.000000
# An Toàn Là Trên Hết                                    1       NaN   2.000000
# Anastasia                                              0       NaN        NaN
# Anh Ba Chị Tư                                          0       NaN        NaN
# Anh Biết (Beat)                                        1       NaN   9.000000
# Anh Biết Em Đi Chẳng Trở Về                            2  2.121320   3.500000
# Anh Biết Em Đã Lãng Quên                               1       NaN   6.000000
# Anh Biết Làm Sao (Remix)                               1       NaN   5.000000
# Anh Cho Em Mùa Xuân                                    4  2.753785   7.250000
# Anh Chàng Sinh Viên Bách Khoa (EDM)                    1       NaN   4.000000
# Anh Chẳng Sao Mà                                       1       NaN   1.000000
# Anh Chẳng Sao Mà (Beat)                                1       NaN   4.000000
# Anh Chẳng Sao Mà (Cover)                               2  1.414214   2.000000
# Anh Chẳng Sao Mà (Remix)                               1       NaN   1.000000
# Anh Chẳng Sao Mà (Version 2)                           1       NaN   2.000000
# Anh Chẳng Sao Mà (Version 2) (Beat)                    1       NaN   5.000000
# Anh Chỉ Cần  Một Tình Yêu                              1       NaN   8.000000
# Anh Chỉ Là Quá Khứ                                     1       NaN   5.000000
# Anh Chỉ Là Quá Khứ (Beat)                              1       NaN   8.000000
# Anh Chỉ Muốn                                           1       NaN   6.000000
# Anh Còn Nhớ Em Không                                   1       NaN   9.000000
# Anh Còn Nợ Em                                          8  2.326094   7.375000
# Anh Còn Yêu Em                                         1       NaN   6.000000
# Anh Có Em Trong Đời (Remix)                            0       NaN        NaN
# Anh Có Lẽ                                              1       NaN   8.000000
# Anh Có Nhớ Em Không?                                   1       NaN   5.000000
# Anh Có Tài Mà                                          0       NaN        NaN
# Anh Có Tài Mà (Beat)                                   1       NaN   3.000000
# Anh Có Về Đây Với Em (Remix)                           1       NaN   1.000000
# Anh Có Đang Lắng Nghe                                  1       NaN   1.000000
# Anh Cần Không                                          0       NaN        NaN
# Anh Em Hãy Cho Họ Ăn                                   2  1.414214   6.000000
# Anh Ghét Em                                            1       NaN   1.000000
# Anh Ghét Em (Acoustic Version)                         1       NaN   2.000000
# Anh Ghét Mùa Đông                                      1       NaN   3.000000
# Anh Ghét Mùa Đông (Beat)                               1       NaN   8.000000
# Anh Gì Ơi (Thanh Xuân Của Anh Viết Tắt Là Em OST)      1       NaN  10.000000
# Anh Hai Xa Quê                                         1       NaN   1.000000
# Anh Hiểu Em Mà                                         1       NaN   2.000000
# Anh Hãy Về Đi                                          2  1.414214   4.000000
# Anh Hùng Bất Tử                                        1       NaN   9.000000
# Anh Hùng Bất Tử (Beat)                                 1       NaN   5.000000
# Anh Hứa                                                1       NaN  10.000000
# Anh Khác Hay Em Khác - Ngỡ (DJ Daniel Mastro Re...     1       NaN   1.000000
# Anh Không Buồn Đâu (Remix)                             1       NaN   5.000000
# Anh Không Buồn Đâu (Remix) (Beat)                      1       NaN   8.000000
# Anh Không Hối Tiếc                                     0       NaN        NaN
# Anh Không Hối Tiếc (Beat)                              1       NaN   7.000000
# Anh Không Làm Được                                     1       NaN   9.000000
# Anh Không Muốn Bất Công Với Em                         1       NaN   1.000000
# Anh Không Muốn Làm Người Lạ                            1       NaN   2.000000
# Anh Không Muốn Làm Người Lạ (Beat)                     2  3.535534   5.500000
# Anh Không Muốn Quay Lại (Remix)                        1       NaN   4.000000
# Anh Không Muốn Quay Lại (Remix) (Beat)                 0       NaN        NaN
# Anh Không Nhường  Em Cho Ai Đâu                        1       NaN   1.000000
# Anh Không Níu Kéo                                      1       NaN  10.000000
# Anh Không Năn Nỉ Em Đâu                                1       NaN   6.000000
# Anh Không Quên                                         1       NaN   6.000000
# Anh Không Thể Làm Gì Hơn                               0       NaN        NaN
# Anh Không Thể Quên                                     0       NaN        NaN
# Anh Không Thể Quên (i won't for get baby)              1       NaN   2.000000
# Anh Không Thể Quên (i won't for get baby) (Beat)       1       NaN   6.000000
# Anh Không Tin                                          1       NaN   1.000000
# Anh Không Tốt Mà                                       1       NaN  10.000000
# Anh Không Vui Chơi Đâu                                 1       NaN   3.000000
# Anh Không Đòi Quà                                      1       NaN   3.000000
# Anh Không Đòi Quà (Glee Vietnam OST - Tập 17)          1       NaN   4.000000
# Anh Luôn Cần Có Em (Beat)                              1       NaN   6.000000
# Anh Luôn Tồn Tại                                       1       NaN  10.000000
# Anh Luôn Tồn Tại (Beat)                                1       NaN  10.000000
# Anh Là Con Rối Của Em (Beat)                           1       NaN   7.000000
# Anh Là Con Rối Của Em (Remix)                          1       NaN   4.000000
# Anh Là Của Em Đừng Của Ai                              1       NaN   1.000000
# Anh Là Gió Em Là Cát                                   1       NaN   2.000000
# Anh Là Người Không Quen                                1       NaN  10.000000
# Anh Là Người Không Quen (Beat)                         1       NaN  10.000000
# Anh Là Soái Sạch 3X (Anh Soái Sạch) (Version Jazz)     1       NaN   2.000000
# Anh Là Soái Sạch 3X (Anh Soái Sạch) (Version Ki...     1       NaN   3.000000
# Anh Là Soái Sạch 3X (Anh Soái Sạch) (Version Pop)      0       NaN        NaN
# Anh Lầm                                                1       NaN   3.000000
# Anh Lầm (Beat)                                         1       NaN   9.000000
# Anh Lỡ Yêu Em                                          1       NaN   6.000000
# Anh Mong Quay Về (Beat)                                1       NaN   5.000000
# Anh Muốn Chia Tay (Gạo Remix)                          1       NaN   7.000000
# Anh Muốn Nghe Giọng Em                                 1       NaN   1.000000
# Anh Muốn Ta Chia Tay                                   1       NaN   2.000000
# Anh Nhớ Em Người Yêu Cũ (Cover)                        0       NaN        NaN
# Anh Nói Em Nghe Đi                                     0       NaN        NaN
# Anh Phải Buông                                         1       NaN   4.000000
# Anh Phải Quên                                          1       NaN   8.000000
# Anh Phải Quên (Beat)                                   1       NaN   9.000000
# Anh Phải Tập Quên                                      0       NaN        NaN
# Anh Phải Tập Quên (Beat)                               1       NaN   8.000000
# Anh Quên Em Gái Quê Rồi                                1       NaN   3.000000
# Anh Quên Em Đi (Acoustic)                              1       NaN   8.000000
# Anh Ra Đi Mùa Nắng                                     0       NaN        NaN
# Anh Say Rồi                                            1       NaN   3.000000
# Anh Sẽ Cố Gắng Quên Em                                 1       NaN   7.000000
# Anh Sẽ Cố Quên                                         1       NaN   4.000000
# Anh Sẽ Hối Hận                                         1       NaN   1.000000
# Anh Sẽ Hối Hận (Vinahouse Remix)                       1       NaN   1.000000
# Anh Sẽ Hồi Hương                                       2  1.414214   4.000000
# Anh Sẽ Không Nói Yêu Em                                1       NaN   1.000000
# Anh Sẽ Kể Em Nghe                                      1       NaN   9.000000
# Anh Sẽ Luôn Thật Gần                                   1       NaN   1.000000
# Anh Sẽ Nhớ Mãi                                         1       NaN   8.000000
# Anh Sẽ Phạt Em                                         1       NaN   1.000000
# Anh Sẽ Quên                                            1       NaN   6.000000
# Anh Sẽ Tốt Thôi                                        1       NaN   4.000000
# Anh Sẽ Tốt Thôi (Remix)                                1       NaN   7.000000
# Anh Sẽ Về                                              1       NaN   1.000000
# Anh Sẽ Về (Beat)                                       1       NaN   8.000000
# Anh Sẽ Về Sớm Thôi                                     1       NaN   1.000000
# Anh Thua Rồi                                           1       NaN   1.000000
# Anh Thua Rồi (Beat)                                    1       NaN   3.000000
# Anh Thì Không                                          1       NaN   2.000000
# Anh Thì Không (Yêu Ư Để Sau OST)                       1       NaN   1.000000
# Anh Thì Không (Yêu Ư Để Sau OST) (Beat)                1       NaN   3.000000
# Anh Thích Thả Thính                                    1       NaN   1.000000
# Anh Thương Em Lắm                                      1       NaN   5.000000
# Anh Trai Của Em                                        1       NaN   1.000000
# Anh Trai Của Em (Beat)                                 1       NaN   5.000000
# Anh Trai Mưa                                           1       NaN   2.000000
# Anh Trai Nắng                                          1       NaN   5.000000
# Anh Trai Nắng (Beat)                                   0       NaN        NaN
# Anh Trai Quốc Dân                                      1       NaN   1.000000
# Anh Vi Cá (Vi Cá Tiền Truyện OST)                      1       NaN   9.000000
# Anh Vui Là Được (Beat)                                 1       NaN   3.000000
# Anh Vẫn Chờ                                            1       NaN   1.000000
# Anh Vẫn Chờ Đợi Em                                     1       NaN   7.000000
# Anh Vẫn Cứ Lo                                          1       NaN   1.000000
# Anh Vẫn Cứ Lo (Beat)                                   1       NaN   6.000000
# Anh Vẫn Hy Vọng (Cương Thi Biến OST)                   1       NaN   4.000000
# Anh Về Miền Tây                                        3  1.000000   8.000000
# Anh Về Quảng Ngãi                                      2  0.707107   6.500000
# Anh Về Quảng Ngãi (Beat)                               1       NaN   9.000000
# Anh Về Với Em                                          2  4.242641   7.000000
# Anh Xa                                                 1       NaN   3.000000
# Anh Xa Mãi                                             0       NaN        NaN
# Anh Xin Em Thứ Tha                                     1       NaN   5.000000
# Anh Xin Em Thứ Tha (Beat)                              1       NaN   9.000000
# Anh Xin Lỗi                                            1       NaN   8.000000
# Anh Xin Thề                                            1       NaN   9.000000
# Anh Yêu Ah...                                          1       NaN  10.000000
# Anh Yêu Em (Beat)                                      0       NaN        NaN
# Anh Yêu Em (DJ Jet Remix)                              1       NaN   1.000000
# Anh Yêu Em Nhiều Lắm (Cover)                           1       NaN   6.000000
# Anh Ác Lắm (Remix)                                     1       NaN   4.000000
# Anh Đang Ở Đâu Đấy Anh                                 1       NaN   4.000000
# Anh Đang Ở Đâu Đấy Anh (Beat Nam)                      1       NaN   2.000000
# Anh Đang Ở Đâu Đấy Anh (Beat Nữ)                       1       NaN   2.000000
# Anh Đang Ở Đâu Đấy Anh (Cover)                         2  6.363961   5.500000
# Anh Đang Ở Đâu Đấy Anh (New Version)                   1       NaN   3.000000
# Anh Đâu Biết Em Thuộc Về Ai                            1       NaN   4.000000
# Anh Đâu Có Hay                                         1       NaN   1.000000
# Anh Đã Biết Yêu                                        1       NaN   1.000000
# Anh Đã Biết Yêu (Remix)                                1       NaN   3.000000
# Anh Đã Biết Yêu (Vinahouse)                            1       NaN   4.000000
# Anh Đã Cố Gắng                                         1       NaN   5.000000
# Anh Đã Cố Gắng Vì Em (Remix)                           1       NaN   1.000000
# Anh Đã Hiểu                                            1       NaN   5.000000
# Anh Đã Mất Cơ Hội Rồi Đấy                              1       NaN   4.000000
# Anh Đã Nhận Ra                                         1       NaN   9.000000
# Anh Đã Quên Em Chưa (Acoustic)                         1       NaN   7.000000
# Anh Đến Thăm Em Đêm 30                                 1       NaN   9.000000
# Anh Đừng Thương Người Ấy                               1       NaN   1.000000
# Anh Ơi! Anh Về Đi                                      1       NaN   1.000000
# Anh Ấy                                                 1       NaN   2.000000
# Anh Ấy Sẽ Không Yêu Em Như Anh (Cover)                 1       NaN  10.000000
# Anh Ở Đây Em Ở Đâu                                     1       NaN   2.000000
# Anh...                                                 0       NaN        NaN
# Anh... (English Version)                               1       NaN  10.000000
# Ao Cá Đợi Chờ                                          0       NaN        NaN
# Ariang Alone                                           1       NaN  10.000000
# Around The World                                       1       NaN  10.000000
# Asian Beauty / Nét Đẹp Á Đông                          1       NaN   2.000000
# Ave Maria                                              1       NaN   9.000000
# Ave Maria Caccini                                      1       NaN   8.000000
# Ave Maria Trăng Từ Bi                                  1       NaN   4.000000
# Avemaria Con Dâng Lời Chào Mẹ                          1       NaN   5.000000
# BYDTET                                                 1       NaN   8.000000
# Ba Bà Đi Bán Lợn Con                                   1       NaN   2.000000
# Ba Em Là Công Nhân Lái Xe                              1       NaN   4.000000
# Ba Kể Con Nghe                                         1       NaN   4.000000
# Ba Lục Bình                                            1       NaN   6.000000
# Ba Mẹ Không Đồng Ý                                     1       NaN   2.000000
# Ba Tháng Tạ Từ                                         5  2.000000   7.000000
# Ba tháng tạ từ                                         1       NaN   4.000000
# Baby Don't Come Back                                   1       NaN   4.000000
# Baby I Told You (Beat)                                 1       NaN   3.000000
# Back To Childhood                                      1       NaN   8.000000
# Bad Boy                                                1       NaN   9.000000
# Bad Boy (Asia Song Festival 2017)                      1       NaN   1.000000
# Bad Girl                                               1       NaN   3.000000
# Bad Girl (Beat)                                        1       NaN  10.000000
# Bae Bae ! Yêu Anh Nhé (Cô Vợ Con Nít OST)              1       NaN   2.000000
# Bae Bae ! Yêu Anh Nhé (Cô Vợ Con Nít OST) (Beat)       1       NaN   5.000000
# Balo & Đi Thôi                                         1       NaN   7.000000
# Bang Bang (My Baby Shot Me Down Cover)                 1       NaN   7.000000
# Bao Giờ Biết Tương Tư (Live)                           1       NaN   5.000000
# Bao Giờ Em Mới Hiểu                                    1       NaN   4.000000
# Bao Lâu Anh Cũng Đợi                                   1       NaN   1.000000
# Bao Lâu Chia Tay (Remix)                               1       NaN   6.000000
# Bao Lâu Chưa Gặp Nhau                                  1       NaN   2.000000
# Bao Lâu Chưa Gặp Nhau (Beat)                           1       NaN   7.000000
# Bao Lâu Mình Cưới                                      1       NaN   1.000000
# Bao Lâu Tôi Mới Có Người Yêu                           1       NaN   8.000000
# Bao Lì Xì Đỏ                                           1       NaN   9.000000
# Bao Ngày Nhớ Bao Ngày Đau                              1       NaN   2.000000
# Bao Nhiêu Tổn Thương                                   1       NaN   1.000000
# Bartender                                              1       NaN   2.000000
# Bautiful Girl                                          0       NaN        NaN
# Bay Cùng Những Đổi Thay                                1       NaN   3.000000
# Bay Lên Cùng Tôi                                       1       NaN   9.000000
# Bay Lên Cùng Việt Nam (Beat)                           1       NaN   9.000000
# Bay Lên Em Ei                                          1       NaN   1.000000
# Bay Lên Những Ước Mơ                                   1       NaN   6.000000
# Be My Lover                                            1       NaN   4.000000
# Because You're Mine                                    1       NaN   1.000000
# Best Friend (Tao Với Mày)                              1       NaN  10.000000
# Biến Tan                                               1       NaN   4.000000
# Biết Bao Giờ Trở Lại                                   1       NaN   7.000000
# Biết Nói Gì Đây                                        2  1.414214   3.000000
# Biết Đau Nhưng Vẫn Yêu                                 1       NaN   1.000000
# Biết Đau Nhưng Vẫn Yêu (Beat)                          1       NaN   2.000000
# Biết Đâu Anh Gặp May                                   1       NaN   3.000000
# Biết đến bao giờ                                       1       NaN   5.000000
# Biết Ơn Chị Võ Thị Sáu                                 1       NaN   4.000000
# Biển Chiều (Eve Ocean)                                 1       NaN  10.000000
# Biển Cạn                                               1       NaN   6.000000
# Biển Dâu                                               1       NaN   2.000000
# Biển Hát Chiều Nay                                     1       NaN   7.000000
# Biển Khuya                                             0       NaN        NaN
# Biển Nhớ                                               2  4.949747   6.500000
# Biển Nỗi Nhớ Và Em                                     1       NaN   8.000000
# Biển Trời Tình Cha                                     1       NaN   2.000000
# Biển Tình                                             10  2.201010   6.200000
# Biển Đợi                                               2  0.000000   9.000000
# Biệt Khúc Mùa Đông                                     1       NaN  10.000000
# Biệt Ly                                                1       NaN   9.000000
# Bolero Miệt Vườn                                       1       NaN   1.000000
# Boom Shakalaka                                         1       NaN   5.000000
# Break Your Man                                         1       NaN   6.000000
# Buông Anh                                              1       NaN   3.000000
# Buông Bàn Tay Thật Nhanh                               1       NaN   1.000000
# Buông Tay Dù Không Muốn                                1       NaN   4.000000
# Buông Tay Dù Không Muốn (Beat)                         0       NaN        NaN
# Buông Tay Là Chia Ly                                   1       NaN  10.000000
# Buông Tay Là Cách Anh Chọn                             1       NaN   3.000000
# Buông Tay Rời Xa                                       1       NaN   5.000000
# Buông Tay Rời Xa (Beat)                                1       NaN   9.000000
# Buồn (Future Bass Remix)                               1       NaN   1.000000
# Buồn Con Sáo Sậu                                       1       NaN  10.000000
# Buồn Của Anh                                           2  2.121320   2.500000
# Buồn Của Anh (Beat)                                    0       NaN        NaN
# Buồn Của Anh (Cover 2)                                 1       NaN   1.000000
# Buồn Của Anh (Cover)                                   8  2.329929   4.000000
# Buồn Của Anh (Cover) (Beat)                            2  4.242641   5.000000
# Buồn Của Anh (K-ICM Mix)                               1       NaN   1.000000
# Buồn Của Anh (Masew Mix)                               1       NaN   1.000000
# Buồn Của Anh (Remix)                                   3  1.154701   1.666667
# Buồn Của Anh (Solo Version)                            1       NaN   6.000000
# Buồn Của Em                                            1       NaN   4.000000
# Buồn Của Em (Buồn Của Anh Cover) (Beat)                1       NaN   2.000000
# Buồn Của Em (Cover)                                    3  1.732051   2.000000
# Buồn Của Em (Remix)                                    2  2.121320   2.500000
# Buồn Không Em                                          1       NaN   1.000000
# Buồn Không Em (Cover)                                  1       NaN   2.000000
# Buồn Là Khi                                            1       NaN  10.000000
# Buồn Lắm Tết Ơi!                                       1       NaN   2.000000
# Buồn Như Trăng                                         1       NaN   8.000000
# Buồn Trong Kỷ Niệm                                     3  2.309401   6.666667
# Buồn Tình Hát Lý Mù U                                  1       NaN   6.000000
# Buồn Vào Đêm                                           2  0.707107   3.500000
# Buồn Vì Ta Mất Nhau                                    1       NaN   1.000000
# Buồn Vì Ta Mất Nhau (Beat)                             1       NaN   5.000000
# Buồn Vương Mi                                          1       NaN   3.000000
# Buồn Vương Màu Áo & Tà Áo Cưới                         1       NaN   6.000000
# Buồn Đến Bao Giờ                                       1       NaN   9.000000
# Buồn Ơi Chào Mi                                        1       NaN  10.000000
# Buồn Ơi Xin Chào Mi                                    0       NaN        NaN
# Buổi Sáng Bình Thường                                  1       NaN   1.000000
# Bà Mẹ Quê                                              4  3.559026   6.000000
# Bà Năm                                                 4  1.892969   7.250000
# Bà Năm (Beat)                                          1       NaN   7.000000
# Bài Ca Dao Đầu Đời                                     1       NaN   3.000000
# Bài Ca Học Sinh                                        0       NaN        NaN
# Bài Ca Học Trò                                         1       NaN   8.000000
# Bài Ca Không Quên                                      0       NaN        NaN
# Bài Ca Kỉ Niệm                                         1       NaN   8.000000
# Bài Ca Kỷ Niệm                                         8  2.672612   7.000000
# Bài Ca Ngày Vu Quy                                     1       NaN   5.000000
# Bài Ca Người Nữ Tự Vệ Sài Gòn                          1       NaN   9.000000
# Bài Ca Phục Vụ (Beat)                                  1       NaN   8.000000
# Bài Ca Queen Wok                                       1       NaN   7.000000
# Bài Ca Sao & Nụ Tầm Xuân                               0       NaN        NaN
# Bài Ca Trang Nứa (Beat)                                1       NaN   9.000000
# Bài Ca Trường Đồng Quan                                1       NaN   8.000000
# Bài Ca Tết Cho Em                                      8  2.375470   8.250000
# Bài Ca Đất Phương Nam                                  0       NaN        NaN
# Bài Không Tên Cuối Cùng                                3  0.000000   8.000000
# Bài Không Tên Số 4                                     1       NaN   7.000000
# Bài Không Tên Số 5                                     1       NaN   3.000000
# Bài Không Tên Số 7                                     1       NaN   5.000000
# Bài Không Tên Số 8                                     1       NaN   7.000000
# Bài Mẹ Không Tên                                       1       NaN   8.000000
# Bài Mẹ Không Tên (Acoustic Version)                    1       NaN   9.000000
# Bài Nhạc Tình Khó Viết                                 1       NaN   8.000000
# Bài Tango Cho Em                                       1       NaN   6.000000
# Bài Tango Cho Người Tình                               1       NaN   7.000000
# Bài Tango Cho Người Tình (Beat)                        0       NaN        NaN
# Bài Thánh Ca Buồn                                      4  3.162278   6.000000
# Bài Thánh Ca Buồn (Beat)                               1       NaN   9.000000
# Bài Thánh Ca Buồn Remix                                1       NaN   3.000000
# Bài Thơ Huế                                            1       NaN   9.000000
# Bài Tình Ca Cho Em                                     1       NaN   8.000000
# Bài Tình Ca Cho Kỹ Niệm                                1       NaN  10.000000
# Bàn Tay Trắng (Glee Vietnam OST - Tập 13)              1       NaN   5.000000
# Bác Làm Vườn Và Con Chim Sâu                           0       NaN        NaN
# Bán Sầu                                                1       NaN   4.000000
# Bánh Gato                                              1       NaN   9.000000
# Bánh Xe Thời Gian                                      1       NaN  10.000000
# Báo Thức                                               1       NaN   7.000000
# Bâng Khuâng Chiều Bên Giáo Đường                       1       NaN   9.000000
# Bâng Khuâng Chiều Nội Trú                              1       NaN   6.000000
# Bây Giờ Em Thế Nào                                     1       NaN   3.000000
# Bây Giờ Em Thế Nào (Beat)                              1       NaN   8.000000
# Bây Giờ Tháng Mấy                                      1       NaN   4.000000
# Bây Giờ Tháng Mấy (Remix)                              1       NaN  10.000000
# Bãi Biển Đêm Trăng                                     1       NaN   6.000000
# Bé Tập Làm Người Mẫu                                   1       NaN   8.000000
# Bé Tập Làm Người Mẫu (Remix) (Beat)                    1       NaN   8.000000
# Bé Về Thăm Quê                                         1       NaN   2.000000
# Bé Yêu Dịu Dàng (Bé Bi Bo)                             1       NaN   5.000000
# Bé Đi Học                                              0       NaN        NaN
# Bé Đánh Răng                                           1       NaN   2.000000
# Bé Đón Tết Sang                                        1       NaN   9.000000
# Bê Đê Miền Tây                                         1       NaN   2.000000
# Bên Anh Lần Cuối (One More Night)                      1       NaN   2.000000
# Bên Cầu Ngó Mong                                       2  2.828427   7.000000
# Bên Em Là Anh (I'll Always Be With You) (Hậu Du...     2  6.363961   5.500000
# Bên Em Là Biển Rộng                                    3  3.055050   4.666667
# Bên Em Là Biển Rộng - Vẫn Hát Lời Tình Yêu             1       NaN   2.000000
# Bên Nhau Bao Lâu                                       1       NaN   2.000000
# Bên Nhau Chỉ Làm Thêm Đau                              1       NaN   3.000000
# Bên Nhau Chỉ Làm Thêm Đau (Beat)                       1       NaN   7.000000
# Bên Nhau Thật Khó (Beat)                               2  2.121320   4.500000
# Bên Nhau Thật Khó (Cover)                              3  2.081666   3.333333
# Bên Nhau Trong Mưa                                     1       NaN   6.000000
# Bên Nhau Được Mấy                                      1       NaN   3.000000
# Bên Nhau Để Ta Bớt Đau                                 1       NaN   6.000000
# Bên Đời Đã Vắng                                        1       NaN   9.000000
# Bên Đời Đông Đơn Côi                                   1       NaN  10.000000
# Bên Ấy Bên Này                                         1       NaN   1.000000
# Bình Dương Quê Em                                      1       NaN   9.000000
# Bình Minh                                              1       NaN  10.000000
# Bình Minh (Sunrise)                                    1       NaN  10.000000
# Bình Tĩnh Sống                                         1       NaN   4.000000
# Bình Tĩnh Sống (Beat)                                  1       NaN  10.000000
# Bình Yên Nhé                                           1       NaN  10.000000
# Bình Yên Nơi Anh                                       1       NaN   1.000000
# Bình Yên Nơi Anh (CM1X x VRT Remix)                    1       NaN   2.000000
# Bình Yên Ở Nơi Nào                                     1       NaN   6.000000
# Bình Yên Ở Nơi Nào (Beat)                              1       NaN   7.000000
# Bí Mật Nhỏ                                             1       NaN   1.000000
# Bó Tay Cuộc Đời                                        1       NaN   4.000000
# Bóng Dáng Mẹ Hiền                                      2  0.000000   8.000000
# Bóng Em Mùa Đông                                       0       NaN        NaN
# Bóng Mát Tình Cha                                      1       NaN   4.000000
# Bóng Nhỏ Giáo Đường                                    1       NaN   6.000000
# Bóng Nhỏ Đường Chiều                                   2  0.000000   5.000000
# Bông Bầu                                               2  4.242641   5.000000
# Bông Hồng Cài Áo                                      10  1.955050   7.600000
# Bông Sầu Đâu                                           1       NaN   3.000000
# Bông Vạn Thọ                                           1       NaN   4.000000
# Bông Ô Môi                                             4  3.000000   5.500000
# Bông Điên Điển                                         1       NaN   3.000000
# Bùa Yêu (Cover)                                        4  1.500000   1.750000
# Bùa Yêu (Edm Version)                                  1       NaN   3.000000
# Bùa Yêu (Remix)                                        1       NaN   2.000000
# Bún Riêu Cua Đồng                                      3  2.309401   2.333333
# Bơ Vơ                                                  1       NaN  10.000000
# Bước Chân Buồn                                         1       NaN  10.000000
# Bước Chân Thần Kỳ                                      1       NaN   2.000000
# Bước Không Em                                          1       NaN   6.000000
# Bước Đi                                                0       NaN        NaN
# Bước Đi Theo Chúa                                      1       NaN   6.000000
# Bước Đi Trong Tình Yêu                                 1       NaN   6.000000
# Bạc Liêu Hoài Cổ                                       3  2.081666   4.666667
# Bạc Liêu Quê Mình                                      1       NaN   5.000000
# Bạc Trắng Lửa Hồng                                     3  2.645751   6.000000
# Bạc Trắng Lửa Hồng (New Version)                       1       NaN  10.000000
# Bạc Trắng Tình Đời                                     1       NaN   7.000000
# Bạc Trắng Tình Đời (Remix)                             1       NaN   5.000000
# Bạc Tình                                               1       NaN   4.000000
# Bạn                                                    1       NaN   1.000000
# Bạn Hữu Thân Tình                                      1       NaN   3.000000
# Bạn Hữu Thân Tình (Beat)                               0       NaN        NaN
# Bạn Thân (Wo De Peng You)                              1       NaN   3.000000
# Bản Tango Hà Nội                                       1       NaN   9.000000
# Bản Tình Ca Của Chàng Nhạc Sĩ                          0       NaN        NaN
# Bản Tình Ca Mùa Đông                                   1       NaN   8.000000
# Bản Tình Cuối                                          2  4.242641   5.000000
# Bảy Ngày Đợi Mong                                      1       NaN   7.000000
# Bảy Sắc Cầu Vồng                                       1       NaN   4.000000
# Bất Chấp Yêu Em                                        1       NaN   4.000000
# Bất Chợt Ta Nhìn Nhau                                  1       NaN   7.000000
# Bần                                                    1       NaN   5.000000
# Bầu Trời Belem                                         1       NaN   8.000000
# Bầu Trời Của Anh                                       1       NaN   7.000000
# Bầu Trời Gọi Tên Em                                    1       NaN  10.000000
# Bận Yêu                                                1       NaN   2.000000
# Bận Yêu (Remix 2)                                      1       NaN   2.000000
# Bận Yêu (Remix)                                        1       NaN   1.000000
# Bắc Kim Thang (Remix)                                  2  3.535534   7.500000
# Bắt Đầu Một Kết Thúc (Cover)                           1       NaN   6.000000
# Bằng Lòng Đi Em                                        2  1.414214   5.000000
# Bằng Lăng Tím Buồn                                     1       NaN   3.000000
# Bến Chờ                                                0       NaN        NaN
# Bến Cũ Đò Xưa                                          1       NaN  10.000000
# Bến Sông Chờ                                           5  2.588436   6.200000
# Bến Thượng Hải (Remix)                                 1       NaN   6.000000
# Bến Thượng Hải (Remix) (Beat)                          1       NaN   8.000000
# Bỏ Anh Đi                                              1       NaN   2.000000
# Bỏ Anh Đi (Beat)                                       1       NaN   9.000000
# Bỏ Bến Sang Sông                                       1       NaN   6.000000
# Bỏ Cả Thế Giới Để Yêu Một Người (Version Ballads)      1       NaN   1.000000
# Bỏ Cả Thế Giới Để Yêu Một Người (Version Ballad...     1       NaN   4.000000
# Bỏ Cả Thế Giới Để Yêu Một Người (Version EDM) f...     1       NaN   3.000000
# Bỏ Giận Quay Về (Chiều Tây Đô 2)                       1       NaN   7.000000
# Bỏ Ngài Con Biết Theo Ai                               2  4.949747   6.500000
# Bỏ Phố Lên Rừng                                        2  2.828427   6.000000
# Bỏ Qua                                                 1       NaN   8.000000
# Bỏ Quên                                                1       NaN   7.000000
# Bố Là Tất Cả (Remix)                                   1       NaN  10.000000
# Bốn Ba Hai Một                                         1       NaN   4.000000
# Bốn Mùa Mưa Lỡ Hẹn                                     0       NaN        NaN
# Bốn Năm Lần                                            1       NaN  10.000000
# Bống Bống Bang Bang (Remix)                            0       NaN        NaN
# Bống Bống Bang Bang (The Remix 2017)                   1       NaN   2.000000
# Bồ                                                     1       NaN   4.000000
# Bồn Bồn Trắng                                          1       NaN   7.000000
# Bội Bạc                                                6  1.673320   6.000000
# Bới Tung Thế Giới                                      1       NaN   7.000000
# Bờ Môi Em                                              1       NaN   8.000000
# Bờ Mộng Mị                                             1       NaN   2.000000
# Bờ Vai Jesus                                           1       NaN   4.000000
# Bờ vai Jeus (New Version)                              1       NaN   9.000000
# Bởi Anh Cần Em                                         1       NaN   2.000000
# Bởi Anh Cần Em (Beat)                                  1       NaN   7.000000
# Bởi Vì Anh Yêu Đơn Phương                              1       NaN   6.000000
# Bởi Vì Anh Yêu Đơn Phương (Remix 2018 Version)         1       NaN   3.000000
# Bụi Bay Vào Mắt                                        1       NaN   3.000000
# Bụi Mờ Phấn Trắng                                      1       NaN   9.000000
# Bụi Phấn                                               2  2.828427   5.000000
# Bức Thư Gửi Lên Thiên Đường (Cover)                    0       NaN        NaN
# Bức Thư Tình Đầu Tiên                                  1       NaN   7.000000
# Bức Tranh Muôn Màu                                     1       NaN   8.000000
# Bức Tranh Đồng Quê                                     1       NaN   8.000000
# Bức Tranh Đồng Quê (Beat)                              1       NaN   9.000000
# Bức Tâm Thư                                            1       NaN   4.000000
# Bứt Phá Vươn Xa                                        1       NaN   6.000000
# Bừng Sáng                                              1       NaN   8.000000
# Ca Dao Em Và Tôi                                       2  2.828427   7.000000
# Ca Dao Mẹ                                              2  0.000000   9.000000
# Ca Dao Tình Mẹ                                         3  1.732051   7.000000
# Ca Khúc Trầm Hương                                     1       NaN   5.000000
# Cafe Đắng Trở Lại                                      1       NaN   9.000000
# Cafe Đắng Và Mưa                                       1       NaN   4.000000
# Can't Take My Eyes Off You (Unit 6)                    1       NaN   3.000000
# Canh Ngoại Nấu                                         2  3.535534   5.500000
# Cao Cung Lên                                           1       NaN   7.000000
# Cao Nguyên Nhớ Em                                      1       NaN   5.000000
# Cao Siêu Phật Pháp                                     2  0.000000   5.000000
# Cao Đài Giáng Thế                                      1       NaN   4.000000
# Catwalk                                                1       NaN   4.000000
# Cau Thắm Trầu Xanh                                     1       NaN   4.000000
# Cause I Love You (Cover)                               0       NaN        NaN
# Cay Đắng                                               1       NaN   5.000000
# Cay Đắng Bờ Môi                                        1       NaN   9.000000
# Cay Đắng Tình Tôi                                      1       NaN   6.000000
# Cay Đắng Tình Đời                                      1       NaN   9.000000
# Cha                                                    1       NaN   6.000000
# Cha - Mẹ - Tuổi Thơ Con                                1       NaN   1.000000
# Cha - Mẹ - Tuổi Thơ Con (Beat)                         1       NaN   3.000000
# Cha Hiền Của Con                                       1       NaN   6.000000
# Cha Mẹ Con Sai Rồi                                     1       NaN   1.000000
# Cha Mẹ Là Tất Cả                                       0       NaN        NaN
# Cha Mẹ Là Tất Cả (Beat)                                1       NaN   9.000000
# Cha Tôi                                                2  1.414214   7.000000
# Cha Va Con Gái                                         1       NaN   1.000000
# Cha Và Con Trai                                        1       NaN   8.000000
# Cha Yêu                                                1       NaN   9.000000
# Cha Yêu Mẹ Yêu                                         1       NaN   7.000000
# Cha Ơi                                                 2  2.828427   6.000000
# Cha Ơi Cha Ở Đâu                                       1       NaN   5.000000
# Cha Ơi!                                                2  1.414214   9.000000
# Cherry Lady                                            1       NaN   7.000000
# Cherry Lady (Beat)                                     0       NaN        NaN
# Chia Tay                                               1       NaN  10.000000
# Chia Tay Ngày Hè                                       0       NaN        NaN
# Chia Tay Người (San Le Ba)                             1       NaN   8.000000
# Chia Tay Nhưng Vẫn Yêu (Remix)                         1       NaN   7.000000
# Chia Tay Nhưng Vẫn Yêu (Remix) (Beat)                  1       NaN   9.000000
# ...
# Đất Biển Quê Em                                       8.0
# Đất Lành Miền Tây                                     8.0
# Đất Nước Lời Ru                                       9.0
# Đất Nước Trong Lời Thầy                               9.0
# Đất Nước Trong Lời Thầy (Beat)                        9.0
# Đất Nước Trọn Niềm Vui                                8.0
# Đầu Xuân Lính Chúc                                    5.0
# Đập Vỡ Cây Đàn                                        6.5
# Đập Vỡ Cây Đàn 2                                      8.0
# Đắc Thắng (Beat)                                      7.0
# Đắm Chìm Tuyệt Vọng                                   9.0
# Đắm Trong Cay Đắng (New Version)                      1.0
# Đắng Cay Tuổi Đôi Mươi                                1.0
# Đắng Cay Tuổi Đôi Mươi (Beat)                         3.0
# Đắp Mộ Cuộc Tình                                      3.0
# Đắp Mộ Cuộc Tình (Beat)                               5.0
# Đắp Mộ Cuộc Tình (Remix)                              1.0
# Đẹp Lắm Cần Thơ                                       7.0
# Đẹp Nhất Là Em                                        NaN
# Đẹp Nhất Là Em (Korean Version)                       1.0
# Đẹp Trai Là Anh                                       6.0
# Đếm Chuỗi Ngày Đau                                    4.0
# Đến Bao Giờ                                           1.0
# Đến Giờ Phút Này Đây                                  6.0
# Đến Khi Em Nhận Ra (Remix)                            2.0
# Đến Khi Mỏi Mòn                                       7.0
# Đến Sau (Remix)                                       NaN
# Đến Sau Một Người (Cover)                             1.0
# Đến Với Chúng Tôi                                     NaN
# Đến Với Chúng Tôi (Beat)                             10.0
# Đến Với Nhau Là Sai (Cover)                           3.0
# Đến Đây Với Anh                                       7.0
# Đến Đây Với Anh (Beat)                                9.0
# Đền Ơn Mẹ Cha                                         5.0
# Để Anh Chứng Minh Tình Yêu                            8.0
# Để Anh Một Mình                                      10.0
# Để Cho Anh Khóc                                       2.0
# Để Cho Anh Khóc (Beat)                                2.5
# Để Cho Anh Khóc (Cover)                               8.0
# Để Cho Anh Khóc (Remix)                               3.0
# Để Cho Anh Khóc (Remix) (Beat)                        NaN
# Để Cho Em Khóc                                        2.5
# Để Cho Em Khóc (Cover)                                2.0
# Để Cho Em Khóc (Remix)                                1.5
# Để Chúa Đến                                           6.0
# Để Con Gánh Thay Nhọc Nhằn                            4.0
# Để Con Gánh Thay Nhọc Nhằn (Beat)                     8.0
# Để Con Tim Dẫn Lối                                    1.0
# Để Dành Giấc Mơ                                       9.0
# Để Dành Nước Mắt (Cover)                              8.0
# Để Em Còn Chút Dỗi Hờn                               10.0
# Để Em Cười Như Xưa                                    1.0
# Để Em Lo                                              1.0
# Để Em Rời Xa (Glee Vietnam OST - Tập 10)              3.0
# Để Em Rời Xa (Remix)                                  3.0
# Để Gió Cuốn Đi                                        NaN
# Để Gặp Chúa Trong Đời                                 6.0
# Để Lại Một Nỗi Đau                                    5.0
# Để Người Khác Trân Trọng Anh                          NaN
# Để Người Khác Trân Trọng Anh (Beat)                   7.0
# Để Nhớ Một Thời Ta Đã Yêu                             7.0
# Để Quá Khứ Ngủ Yên                                    1.0
# Để Quên Con Tim                                       NaN
# Để Rồi Xem (Let's See)                                4.0
# Để Tang Tình Đầu                                      2.0
# Để Trả Lời Một Câu Hỏi                                6.0
# Định Mệnh                                             9.0
# Định Nghĩa Vô Thường                                  4.0
# Định Nghĩa Vô Thường (Beat)                           9.0
# Đố Ai Hiểu Được Mẹ                                    5.0
# Đố Em Biết Anh Đang Nghĩ Gì                           1.0
# Đồ                                                    9.0
# Đồ Chơi Đất                                           NaN
# Đồ Ngon                                               5.0
# Đồi Hoa Mặt Trời                                      1.0
# Đồi Thông Hai Mộ                                      6.0
# Đồng Cảnh Ngộ                                         2.0
# Đồng Hành                                            10.0
# Đổi Thay                                              5.5
# Độc Thân                                              NaN
# Độc Thân Không Phải Là Ế                              NaN
# Độc Tình (Beat)                                       9.0
# Đội Kèn Tí Hon                                        3.0
# Động Lòng Rơi Nước Mắt                                4.0
# Động Lòng Rơi Nước Mắt  (Beat)                        8.0
# Đớn Đau Anh Vẫn Yêu                                   4.0
# Đời Anh Vẫn Cô Đơn                                    9.0
# Đời Ca Sĩ                                             NaN
# Đời Của Nó                                            1.0
# Đời Doanh Nhân                                        NaN
# Đời Dạy Tôi (Ông Ngoại Tuổi 30 OST)                   4.0
# Đời Dạy Tôi (Ông Ngoại Tuổi 30 OST) (Beat)            5.0
# Đời Không Còn Nhau                                    9.0
# Đời Long Đong                                         8.0
# Đời Là Cõi Tạm                                        2.0
# Đời Là Những...                                      10.0
# Đời Là Thế Thôi                                      10.0
# Đời Là Thế Thôi (Acoustic Version)                    8.0
# Đời Là Vậy                                            6.0
# Đời Là Vậy (Beat Bè)                                  9.0
# Đời Làm Thuê                                          7.0
# Đời Mà                                                4.5
# Đời Nghèo                                             7.0
# Đời Người                                             4.0
# Đời Nó Bạc                                            1.0
# Đời Tôi Cô Đơn                                        6.5
# Đời Tôi Cô Đơn Remix                                  3.0
# Đời Vẫn Lang Thang                                    4.0
# Đời Xe Ôm (Remix)                                     2.0
# Đời Đá Vàng                                           7.0
# Đời Đẹp Lắm                                           6.0
# Đợi                                                   2.5
# Đợi Anh                                               9.0
# Đợi Anh (Beat)                                       10.0
# Đợi Anh Đợi Đến Hoa Cũng Tàn                          1.0
# Đợi Cho Những Hạt Mưa Ngừng Rơi (Cover)               6.0
# Đợi Chờ                                               9.0
# Đợi Chờ Làm Chi (Beat)                                8.0
# Đợi Em                                                9.0
# Đợi Em Trong Mơ (Remix)                               4.0
# Đợi Tình                                              6.0
# Đứa Bé                                                NaN
# Đức Hóa Bốn Mùa Thương                                8.0
# Đứng Cạnh Nỗi Đau                                     9.0
# Đứng Sau Một Cuộc Tình (Beat)                         3.0
# Đứt Từng Đoạn Ruột                                    5.0
# Đừng (Piano Version)                                  6.0
# Đừng Buồn Ta Hỡi                                      9.0
# Đừng Bận Tâm Anh                                      8.0
# Đừng Bắt Anh Nuôi Hy Vọng                             2.0
# Đừng Bắt Anh Nói Xa Em (Remix)                        2.0
# Đừng Bỏ Con Chúa Ơi                                   5.0
# Đừng Chờ Anh Nữa                                      1.0
# Đừng Cố Yêu Khi Không Còn Cảm Giác                   10.0
# Đừng Cố Yêu Khi Tàn Phai                              1.0
# Đừng Dối Lòng                                         3.0
# Đừng Dối Lòng (Beat)                                  8.0
# Đừng Dối Lòng (DJ Hiếu Phan Mix)                      3.0
# Đừng Giận Anh Em Nhé                                  NaN
# Đừng Giận Anh Nhé                                     1.0
# Đừng Giận Anh Nhé (Beat)                              NaN
# Đừng Giận Anh Nữa                                     1.0
# Đừng Giận Mẹ                                          8.0
# Đừng Giữ Trong Lòng (Remix)                           NaN
# Đừng Giữ Trong Lòng (Remix) (Beat)                    8.0
# Đừng Gọi Anh Là Idol                                  NaN
# Đừng Hẹn Ước                                          NaN
# Đừng Hỏi Anh                                          NaN
# Đừng Hỏi Em (Cover)                                   1.0
# Đừng Hỏi Em (K-ICM Mix)                               1.0
# Đừng Hứa                                              9.0
# Đừng Hứa Với Em                                       6.0
# Đừng Khóc Làm Anh Đau                                 1.0
# Đừng Khóc Vì Anh                                      1.0
# Đừng Khóc Vì Anh (Beat)                               2.0
# Đừng Là Ký Ức                                         4.0
# Đừng Làm Anh Khóc 2                                   NaN
# Đừng Lừa Dối                                          5.0
# Đừng Lừa Dối (Beat)                                   8.0
# Đừng Nghĩ Mình Là Duy Nhất                            2.0
# Đừng Ngăn Cách Giàu Nghèo                             7.0
# Đừng Ngồi Yên Trong Bóng Tối (Glee Vietnam OST ...    4.0
# Đừng Như Thói Quen                                    4.5
# Đừng Như Thói Quen (Chinese Version)                  2.0
# Đừng Như Thói Quen (Chinese Version) (Beat Nam)       5.0
# Đừng Như Thói Quen (Chinese Version) (Beat Nữ)        NaN
# Đừng Như Thói Quen (Chinese Version) (Beat)           NaN
# Đừng Như Thói Quen (Cover)                            2.0
# Đừng Như Thói Quen (Cover) (Beat Bè)                  NaN
# Đừng Như Thói Quen (Cover) (Beat Nữ)                  3.0
# Đừng Như Thói Quen (Cover) (Beat)                     7.0
# Đừng Như Thói Quen (DinhLong Mix)                     2.0
# Đừng Như Thói Quen (Korean Version)                   1.0
# Đừng Như Thói Quen (Remix)                            1.5
# Đừng Như Thế                                          4.0
# Đừng Nhắc Chuyện Lòng                                 4.0
# Đừng Nhắc Chuyện Đau Lòng                             7.0
# Đừng Nuối Tiếc (Beat)                                10.0
# Đừng Nuối Tiếc (New Version)                          9.0
# Đừng Nói Lời Chia Tay                                 1.0
# Đừng Nói Tôi Điên                                     1.0
# Đừng Nói Tôi Điên (Beat)                              2.0
# Đừng Nói Và Đừng Hứa (Glee Vietnam OST - Tập 14)      6.0
# Đừng Nói Xa Nhau                                      7.5
# Đừng Nói Xa Nhau (Live)                               8.0
# Đừng Nói Yêu Tôi                                      8.0
# Đừng Phụ Lòng Nhau                                    3.0
# Đừng Quên Câu Dân Ca                                  4.0
# Đừng Quên Tên Anh                                     1.0
# Đừng Quên Tên Anh (C.A.O Mix)                         9.0
# Đừng Quên Tên Anh (Cover)                             7.0
# Đừng Tin Trai Đẹp                                     NaN
# Đừng Trách Anh Tội Nghiệp                             5.0
# Đừng Trách Cha Mẹ Nghèo                               8.0
# Đừng Trách Cha Mẹ Nghèo (Beat)                        9.0
# Đừng Trách Em Tội Nghiệp                              4.0
# Đừng Trách Người Ơi                                   7.0
# Đừng Trách Sáo Sang Sông                              6.0
# Đừng Trách Trái Mồng Tơi                              9.0
# Đừng Trốn Trong Phòng                                 5.0
# Đừng Tìm Anh Nữa                                      1.0
# Đừng Tự Chuốc Lấy Tổn Thương                          3.0
# Đừng Tự Chuốc Lấy Tổn Thương (Beat)                   8.0
# Đừng Ví Em Là Biển                                    9.0
# Đừng Vô Tâm                                           1.0
# Đừng Vô Tâm (Beat)                                    3.0
# Đừng Vội Vàng Đổi Thay                                1.0
# Đừng Xa Em Nhé                                        2.0
# Đừng Xa Em Nhé (Remix) (Cover)                        7.0
# Đừng Xa Em Đêm Nay                                    8.0
# Đừng Xa Nhau Nhé (Remix)                              7.0
# Đừng Xa Nhau Nữa Nhé                                  5.0
# Đừng Xa Tôi                                           1.0
# Đừng Xem Ai Đó Là Cả Thế Giới                         5.0
# Đừng Xem Như Trò Chơi                                 4.0
# Đừng Xin Lỗi Nữa (Cover)                              2.5
# Đừng Yêu Ai Đó Quá Nhiều                              4.0
# Đừng Yêu Ai Đó Quá Nhiều (Beat)                       NaN
# Đừng Yêu Cho Mình                                     2.0
# Đừng Yêu Cho Mình (Beat)                              8.0
# Đừng Đi Anh Cần Em                                    2.0
# Đừng Đi Anh Cần Em (Beat)                             8.0
# Đừng Đi Mà                                            NaN
# Đừng Để Anh Thất Vọng                                 5.0
# Đừng Để Anh Thất Vọng (Beat)                          9.0
# Đừng Đợi Xuân Đến Gần                                 5.0
# Ơi Con Sông Ngàn Phố                                  7.0
# Ơn Cha                                                9.0
# Ơn Mẹ                                                 6.5
# Ơn Nghĩa Sinh Thành                                   8.0
# Ơn Thầy Cứu Khổ Đời Con                               4.0
# Ơn Thầy Cứu Khổ Đời Con (Beat)                       10.0
# Ưu Tư                                                 5.0
# Ước Chi Em Sẽ                                         NaN
# Ước Gì                                                6.0
# Ước Gì (Beat)                                         2.0
# Ước Gì (Ông Ngoại Tuổi 30 OST)                        1.0
# Ước Muốn                                             10.0
# Ước Mơ Của Mẹ                                         6.0
# Ước Nguyện Mùa Xuân                                   6.0
# Ước Nguyện Đầu Xuân                                   8.0
# Ướt Lem Chữ Đời                                       3.5
# Ảo Giác                                               7.0
# Ảo Giác (Beat)                                       10.0
# Ảo Giác (No Rap)                                      6.0
# Ảo Giác Cuộc Đời                                      1.0
# Ảo Mộng Tình Yêu (Cover)                              NaN
# Ảo Mộng Tình Yêu (Thiên Ý OST)                        2.5
# Ảo Ảnh                                                6.0
# Ấm No Đời Đời                                         1.0
# Ấm Tình Quê Bác                                       6.0
# Ấp Úng                                                1.0
# Ế                                                     2.0
# Ở Bên Em (Beat)                                       9.0
# Ở Kiếp Sau Anh Vẫn Yêu Em                             NaN
# Ở Lại Bên Em                                         10.0
# Ở Nhà Thôi                                            5.0
# Ở Nhà Thôi (Beat)                                     9.0
# Ở Nơi Đó Em Cười                                      8.0
# Ở Rễ                                                  6.0
# Ở Trong Thành Phố (Masew Mix)                         1.0
# Ủa Bồ Tui Đâu?                                        NaN
# Ừ Có Anh Đây                                          4.0
# Ừ Có Anh Đây (Beat)                                   5.0
# Ừ Có Anh Đây (Cover)                                  NaN
# Ừ Thì Thôi                                            9.0

# %%
import seaborn as sns
# Fill nan album
print("There is {} ratio is nan album".format(len(df[df["album"].isnull()])/len(df)))
df["album"]  = df["album"].fillna("")
df["len_album_name"] = df["album"].apply(lambda x: len(x.split(" ")))
df["isRemixAlbum"] = [ 1 if "Remix" in t else 0 for t in df["album"]]
df["isOSTAlbum"] = [ 1 if "OST" in t else 0 for t in df["album"]]
df["isSingleAlbum"] = [ 1 if "Single" in t else 0 for t in df["album"]]
df["isBeatAlbum"] = [ 1 if "Beat" in t else 0 for t in df["album"]]
df["isTopHitAlbum"] = [ 1 if "Top Hits" in t else 0 for t in df["album"]]
df["isCoverAlbum"] = [ 1 if "Cover" in t else 0 for t in df["album"]]
df["isEPAlbum"] = [ 1 if "EP" in t else 0 for t in df["album"]]
df["isLienKhucAlbum"] = [ 1 if "Liên Khúc" in t else 0 for t in df["album"]]

df["album_name_is_title_name"]= [1 if r.title in r.album  else 0 for i,r in df.iterrows() ]
df["album"] = df["album"].astype('category')
df["album"] =  df["album"].cat.codes

df["artist_name_cat"] = df["artist_name"].astype('category')
df["artist_name_cat"] =  df["artist_name_cat"].cat.codes
df["composers_name_cat"] = df["composers_name"].astype('category')
df["composers_name_cat"] =  df["composers_name_cat"].cat.codes
df["copyright_cat"] = df["copyright"].astype('category')
df["copyright_cat"] =  df["copyright_cat"].cat.codes

import re
def get_min_artist_id(s):
    ps = re.split(',|\.',s)
    ps = [int(p) for p in ps]
    return np.min(ps)

def get_max_artist_id(s):
    ps = re.split(',|\.',s)
    ps = [int(p) for p in ps]
    return np.max(ps)

df["artist_id_min"]=  df["artist_id"].apply(lambda x: get_min_artist_id(x))
df["artist_id_min_cat"] = df["artist_id_min"].astype('category')
df["artist_id_min_cat"] =  df["artist_id_min_cat"].cat.codes

df["composers_id_min"]=  df["composers_id"].apply(lambda x: get_min_artist_id(x))
df["composers_id_min_cat"] = df["composers_id_min"].astype('category')
df["composers_id_min_cat"] =  df["composers_id_min_cat"].cat.codes

df["artist_id_max"]=  df["artist_id"].apply(lambda x: get_max_artist_id(x))
df["artist_id_max_cat"] = df["artist_id_max"].astype('category')
df["artist_id_max_cat"] =  df["artist_id_max_cat"].cat.codes

df["composers_id_max"]=  df["composers_id"].apply(lambda x: get_max_artist_id(x))
df["composers_id_max_cat"] = df["composers_id_max"].astype('category')
df["composers_id_max_cat"] =  df["composers_id_max_cat"].cat.codes

#New feature
# df["group_album_artist_id_min_cat"] = df.groupby(["album","artist_id_min_cat"]).ngroup()
# df["group_album_artist_id_min_cat"] = df["group_album_artist_id_min_cat"].astype("category").cat.codes
# df["group_album_artist_id_max_cat"] = df.groupby(["album","artist_id_max_cat"]).ngroup()
# df["group_album_artist_id_max_cat"] = df["group_album_artist_id_max_cat"].astype("category").cat.codes


# Fill genre
print("There is {} ratio is nan genre".format(len(df[df["genre"].isnull()])/len(df)))
df["genre"]  = df["genre"].fillna("No genre")
df["genre"] = df["genre"].astype('category')
df["genre"] =  df["genre"].cat.codes

# Fill album_artist
print("There is {} ratio is nan album_artist".format(len(df[df["album_artist"].isnull()])/len(df)))
df["album_artist"]  = df["album_artist"].fillna("No album_artist")
df["album_artist_contain_artistname"]= [1 if r.album_artist in r.artist_name  else 0 for i,r in df.iterrows() ]
df["album_artist"] = df["album_artist"].astype('category')
df["album_artist"] =  df["album_artist"].cat.codes

# Fill track
print("There is {} ratio is nan track".format(len(df[df["track"].isnull()])/len(df)))
df["track"]  = df["track"].fillna("(1, 1)")
df["istrack11"] = df["track"] == "(1, 1)"
def tracknum_to_value(track_num):
    try:
        
        track_num = make_tuple(track_num)
        if track_num[0] is not None:
            return float(track_num[0]) / float(track_num[1])
        else:
            return 1.0
    except:
        return 1.0

df["track"] = df["track"].apply(lambda t: tracknum_to_value(t))


# Fill lyric
print("There is {} ratio is nan lyric".format(len(df[df["lyric"].isnull()])/len(df)))
df["lyric"]  = df["lyric"].fillna("")
df["islyric"] = df["lyric"].apply(lambda x:  True if len(x)  else False)
df["num_line_lyric"] = df["lyric"].apply(lambda x : len(x.split("\r")))


#--------------------------------------------------------
from dateutil import relativedelta
from datetime import datetime
from sklearn.preprocessing import LabelEncoder
from ast import literal_eval as make_tuple
df['no_artist'] = df.artist_name.apply(lambda x: len(x.split(",")))
df['no_composer'] = df.composers_name.apply(lambda x: len(x.split(",")))
df["freq_artist"] = df.groupby('artist_id')['artist_id'].transform('count').astype('float')
df["freq_composer"] = df.groupby('composers_id')['composers_id'].transform('count').astype('float')
df["freq_artist_min"] = df.groupby('artist_id_min_cat')['artist_id_min_cat'].transform('count').astype('float')
df["freq_composer_min"] = df.groupby('composers_id_min_cat')['composers_id_min_cat'].transform('count').astype('float')

df["num_album_per_min_artist"] = df.groupby(['artist_id_min_cat','album'])['album'].transform('count').astype('float')
df["num_album_per_min_composer"] = df.groupby(['composers_id_min','album'])['album'].transform('count').astype('float')


df["datetime"] = pd.to_datetime(df.release_time)
df["year"] = df["datetime"].dt.year
df["month"] = df["datetime"].dt.month
df["hour"] = df["datetime"].dt.hour
df["day"] = df["datetime"].dt.day
df["dayofyear"] = df["datetime"].dt.dayofyear
df["weekday"] = df["datetime"].dt.weekday
from datetime import date 
import holidays 

in_holidays = holidays.HolidayBase() 
for i in range(26,32):
    in_holidays.append(str(i)+'-01-2017')
in_holidays.append('01-02-2017')
for i in range(14,21):
    in_holidays.append(str(i)+'-02-2018')
in_holidays.append('30-04-2017')
in_holidays.append('30-04-2018')
in_holidays.append('01-01-2017')
in_holidays.append('01-01-2018')
in_holidays.append('14-02-2017')
in_holidays.append('14-02-2018')
in_holidays.append('08-03-2017')
in_holidays.append('08-03-2018')
in_holidays.append('01-05-2017')
in_holidays.append('01-05-2018')
in_holidays.append('06-04-2017')
in_holidays.append('25-04-2018')
in_holidays.append('01-06-2017')
in_holidays.append('01-06-2018')
in_holidays.append('04-10-2017')
in_holidays.append('24-09-2018')
in_holidays.append('20-10-2017')
in_holidays.append('20-10-2018')
in_holidays.append('20-11-2017')
in_holidays.append('20-11-2018')
in_holidays.append('24-12-2017')
in_holidays.append('24-12-2018')
df['isHoliday'] = df.release_time.apply(lambda x: x in in_holidays)



df["len_of_songname"] = df["title"].apply(lambda x: len(x.split(" ")))
df["isRemix"] = [ 1 if "Remix" in t else 0 for t in df["title"]]
df["isOST"] = [ 1 if "OST" in t else 0 for t in df["title"]]
df["isBeat"] = [ 1 if "Beat" in t else 0 for t in df["title"]]
df["isVersion"] = [ 1 if "Version" in t else 0 for t in df["title"]]
df["isCover"] = [ 1 if "Cover" in t else 0 for t in df["title"]]
df["isLienKhuc"] = [ 1 if "Liên Khúc" in t else 0 for t in df["title"]]



def find_num_song_release_in_final_month(df, day):
    month5th = day + relativedelta.relativedelta(months=5)
    month6th = day + relativedelta.relativedelta(months=6)  
    return len(df.datetime[(df.datetime >= month5th)&(df.datetime<=month6th)])



df["num_song_release_in_final_month"] = df.datetime.apply(lambda d:find_num_song_release_in_final_month(df ,d))

#It seems like all songs on albums release at the same time, so groupby by release_time will create album 
df["album_right"] = df.groupby(df.release_time).ngroup().astype("category").cat.codes
df["day_release"] = df.groupby(["year","dayofyear"]).ngroup().astype("category").cat.codes
df["numsongInAlbum"] = df.groupby("album_right")["album_right"].transform("count")
df["isSingleAlbum_onesong"]= df["isSingleAlbum"] & (df["numsongInAlbum"]==1)
# Out:
# There is 0.24038838760298156 ratio is nan album
# There is 0.0017653981953707335 ratio is nan genre
# There is 0.24038838760298156 ratio is nan album_artist
# There is 0.0007846214201647705 ratio is nan track
# There is 0.6722244017261672 ratio is nan lyric

# %%
from datetime import datetime
import re

def split_id(s):
    return re.split(',|\.',s)

m = df.artist_id.unique()
idx_lst = []
for idx in m:
    ps = split_id(idx)
    for i in ps:
        idx_lst.append(i)
        
id_lst = list(set(idx_lst))

def condition(df, artist_id):
    r = df.artist_id.apply(lambda x: artist_id in split_id(x))
    return r

df_train = df[df.dataset=="train"]
data= [df_train[condition(df_train, artist_id)].label.agg(["mean","std","count"]) for artist_id in id_lst]
new_df = pd.DataFrame(data=data)
new_df["artist_id"] =  id_lst

new_df.dropna(inplace=True)
new_df.set_index('artist_id', inplace=True)
art_dict = new_df.to_dict()

def best_count_id(values):
    ids = split_id(values)
    temp_mean = 0
    temp_id = str(min([int(a) for a in ids]))
    for id in ids:
        try:
            if art_dict['count'][id] > temp_mean:
                temp_mean = art_dict['count'][id]
                temp_id = id
        except:
            temp_mean = temp_mean
            temp_id = temp_id
    return temp_id
    
df['artist_count_id'] = df['artist_id'].apply(best_count_id)

def best_mean_id(values):
    ids = split_id(values)
    temp_mean = 10
    temp_id = str(min([int(a) for a in ids]))
    for id in ids:
        try:
            if art_dict['mean'][id] < temp_mean:
                temp_mean = art_dict['mean'][id]
                temp_id = id
        except:
            temp_mean = temp_mean
            temp_id = temp_id
    return temp_id

df['artist_mean_id'] = df['artist_id'].apply(best_mean_id)

def best_std_id(values):
    ids = split_id(values)
    temp_std = 10
    temp_id = str(min([int(a) for a in ids]))
    for id in ids:
        try:
            if art_dict['std'][id] < temp_std:
                temp_std = art_dict['std'][id]
                temp_id = id
        except:
            temp_std = temp_std
            temp_id = temp_id
    return temp_id

df['artist_std_id'] = df['artist_id'].apply(best_std_id)

df['artist_mean_id'] = df['artist_mean_id'].astype('category')
df['artist_std_id'] = df['artist_std_id'].astype('category')
df['artist_count_id'] = df['artist_count_id'].astype('category')

# %%
from functools import reduce

def create_album_score_lookup_table(df):
    data = df.groupby('album_right').label.agg(["mean","std","count"])
    return data

def create_artist_score_lookup_table(df):
    def split_id(s):
        return re.split(',|\.',s)
    
    def mask_row_contain_artist_id(df, artist_id):
        r = df.artist_id.apply(lambda x: artist_id in split_id(x))
        return r
    
    # Get all artist ids
    artist_group = df.artist_id.unique()
    artist_ids = reduce(lambda l,e: l+split_id(e), artist_group, [])
    artist_ids = list(set(artist_ids))
    # Get data
    data= [df[mask_row_contain_artist_id(df, artist_id)].label.agg(["mean","std","count", "median"]) 
                                                        for artist_id in artist_ids]
    new_df = pd.DataFrame(data=data)
    new_df["artist_id"] =  artist_ids
    return new_df.set_index("artist_id")

# %%
def get_field_by_key(table, k, field="mean"):
    if k in table.index:
        return table.loc[k][field]
    return np.nan

def get_value_by_key(table, k):
    if k in table.index:
        return table.loc[k], False
    return np.nan, True

def assign_value(album_table, artist_table, r):
    d1,isnul1 = get_value_by_key(album_table, r.album_right)
    d2,isnul2 = get_value_by_key(artist_table, r.artist_id_min_cat)
#     print(type(d2),isnul2)
    if isnul1 and isnul2:
        return np.nan
    elif isnul1 and d2["std"] <2:
        return d2["mean"]
    elif isnul2 and d1["std"] <2:
        return d1["mean"]
    
    elif not isnul1 and d1["std"] <2 and not isnul2 and d2["std"] < 2:
        return d1["mean"] 
    
    
    return np.nan

def assign_value_album(album_table, r):
    d1,isnul1 = get_value_by_key(album_table, r.album_right)
    
    if not isnul1 and d1["std"] <3.5:
        return d1["std"]
    
    return np.nan
    
def assign_value_artist(artist_table, r):
    d1,isnul1 = get_value_by_key(artist_table, r.artist_id_min_cat)
    
    if not isnul1 and d1["std"] <3.5:
        return d1["std"]
    
    return np.nan

# %%
from sklearn.neural_network import MLPRegressor
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from math import sqrt

from sklearn.model_selection import train_test_split

# chosen_features = ["album_right", "istrack11", "no_artist", "no_composer","freq_artist", "freq_composer","year", "month","hour", "day", "len_of_songname", 
#                    "isRemix", "isOST", "isBeat", "isVersion", "isCover",  "num_song_release_in_final_month",
#                   "length", "genre", "track","album_artist", "islyric", "album_artist_contain_artistname",
#                   "len_album_name", "isRemixAlbum", "isOSTAlbum", "isSingleAlbum", "album_name_is_title_name",
#                   "isBeatAlbum", "isCoverAlbum", "artist_name_cat","composers_name_cat","copyright_cat" ,
#                   "artist_id_min_cat", "composers_id_min_cat",  "artist_id_max_cat", "composers_id_max_cat", 
#                    "freq_artist_min", "freq_composer_min","dayofyear","weekday","isHoliday",
#                   "num_album_per_min_artist", "num_album_per_min_composer", 
#                    "numsongInAlbum","isSingleAlbum_onesong" ]

chosen_features = [ "album_right", "istrack11", "no_artist", "no_composer","freq_artist", "freq_composer","year", "month","hour", "day", "len_of_songname", 
                   "isRemix", "isOST", "isBeat", "isVersion", "isCover",  "num_song_release_in_final_month",
                  "length", "genre", "track","album_artist", "islyric", "album_artist_contain_artistname",
                  "len_album_name", "isRemixAlbum", "isOSTAlbum", "isSingleAlbum", "album_name_is_title_name",
                  "isBeatAlbum", "isCoverAlbum", "artist_id_cat","composers_id_cat","copyright_cat" ,
                  "artist_id_min_cat",  "artist_id_max_cat","composers_id_min_cat",
                   "freq_artist_min", "freq_composer_min","dayofyear","weekday",
                  "num_album_per_min_artist", "num_album_per_min_composer", 
                   "numsongInAlbum","isSingleAlbum_onesong","artist_mean_id", "artist_std_id" ,"artist_count_id" ]

# chosen_features = [  "istrack11", "no_artist", "no_composer","freq_artist", "freq_composer","year", "month","hour", "day", "len_of_songname", 
#                    "isRemix", "isOST", "isBeat", "isVersion", "isCover",  "num_song_release_in_final_month",
#                   "length", "genre", "track", "islyric", "album_artist_contain_artistname",
#                   "len_album_name", "isRemixAlbum", "isOSTAlbum", "isSingleAlbum", "album_name_is_title_name",
#                   "isBeatAlbum", "isCoverAlbum","copyright_cat" ,
#                    "freq_artist_min", "freq_composer_min","dayofyear","weekday",
#                   "num_album_per_min_artist", "num_album_per_min_composer", 
#                    "numsongInAlbum","isSingleAlbum_onesong"]

# chosen_features = ["isRemix", "isOST", "isBeat", "isVersion", "isCover",  "istrack11", "no_artist", "no_composer","freq_artist", "freq_composer"]
# chosen_features  += ["predicted_label"]
# chosen_features += ["mean_album_score", "mean_artist_min_score"]
df_train = df[df.dataset=="train"]
df_test = df[df.dataset=="test"]



folds = StratifiedKFold(n_splits=10, shuffle=True, random_state=99999)
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
labels= df_train.label
# fig, axes = plt.subplots(5, 1, figsize=(10, 10*5))
# axes = axes.flat
for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train.values, df_train.label.values)):
    print("Fold {}".format(fold_))
    
    # Create lookup table
    album_lookup_table = create_album_score_lookup_table(df_train.iloc[trn_idx])
    artist_lookup_table = create_artist_score_lookup_table(df_train.iloc[trn_idx])
    
#     df_train["mean_album_score"]= [assign_value_album(album_lookup_table, r) for i, r in df_train.iterrows()]
#     df_train["mean_artist_min_score"]= [assign_value_artist(artist_lookup_table, r) for i, r in df_train.iterrows()]
#     df_train["mean_album_score"] = df_train["mean_album_score"].fillna(0)
#     df_train["mean_artist_min_score"] = df_train["mean_artist_min_score"].fillna(0)
    
    df_train["predicted_label"] = [assign_value(album_lookup_table,artist_lookup_table, r) for i, r in df_train.iterrows()]
    df_train["predicted_label"] =df_train["predicted_label"].fillna(0)
    
    mlp = MLPRegressor(verbose=True,early_stopping=True)

    mlp.fit(df_train.iloc[trn_idx][chosen_features].values,labels.iloc[trn_idx])
    oof[val_idx] = mlp.predict(df_train.iloc[val_idx][chosen_features].values)
    print("RMSE: {:<8.5f}".format(sqrt(mean_squared_error(labels.iloc[val_idx], oof[val_idx]))))
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][chosen_features], num_iteration=clf.best_iteration)
    predictions += clf.predict(df_test[chosen_features], num_iteration=clf.best_iteration) / folds.n_splits
# Out:
# Fold 0
# /home/vuthede/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/ipykernel_launcher.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/vuthede/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/ipykernel_launcher.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-30482623879f> in <module>
#      68     mlp = MLPRegressor(verbose=True,early_stopping=True)
#      69
# ---> 70     mlp.fit(df_train.iloc[trn_idx][chosen_features].values,labels.iloc[trn_idx])
#      71     oof[val_idx] = mlp.predict(df_train.iloc[val_idx][chosen_features].values)
#      72     print("RMSE: {:<8.5f}".format(sqrt(mean_squared_error(labels.iloc[val_idx], oof[val_idx]))))
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
#    3003         # take() does not accept boolean indexers
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# ~/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1183             if not (self.name == "loc" and not raise_missing):
#    1184                 not_found = list(set(key) - set(ax))
# -> 1185                 raise KeyError("{} not in index".format(not_found))
#    1186
#    1187             # we skip the warning on Categorical/Interval
#
# KeyError: "['composers_id_cat', 'artist_id_cat'] not in index"

# %%
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler


from sklearn.model_selection import train_test_split

chosen_features = ["album_right", "istrack11", "no_artist", "no_composer","freq_artist", "freq_composer","year", "month","hour", "day", "len_of_songname", 
                   "isRemix", "isOST", "isBeat", "isVersion", "isCover",  "num_song_release_in_final_month",
                  "length", "genre", "track","album_artist", "islyric", "album_artist_contain_artistname",
                  "len_album_name", "isRemixAlbum", "isOSTAlbum", "isSingleAlbum", "album_name_is_title_name",
                  "isBeatAlbum", "isCoverAlbum", "artist_name_cat","composers_name_cat","copyright_cat" ,
                  "artist_id_min_cat", "composers_id_min_cat",  "artist_id_max_cat", "composers_id_max_cat", 
                   "freq_artist_min", "freq_composer_min","dayofyear","weekday","isHoliday",
                  "num_album_per_min_artist", "num_album_per_min_composer", 
                   "numsongInAlbum","isSingleAlbum_onesong","artist_mean_id","artist_std_id" ,"artist_count_id" ]

# chosen_features = ["album_right","freq_artist",  "day", 
#                      "isBeat",  "num_song_release_in_final_month",
#                   "length","album_artist",
#                   "artist_name_cat","composers_name_cat",
#                   "artist_id_min_cat", "composers_id_min_cat",  "artist_id_max_cat", "composers_id_max_cat", 
#                    "freq_artist_min","dayofyear", 
#                    "numsongInAlbum","artist_mean_id","artist_std_id" ,"artist_count_id" ]


# chosen_features = [  "istrack11", "no_artist", "no_composer","freq_artist", "freq_composer","year", "month","hour", "day", "len_of_songname", 
#                    "isRemix", "isOST", "isBeat", "isVersion", "isCover",  "num_song_release_in_final_month",
#                   "length", "genre", "track","album_artist", "islyric", "album_artist_contain_artistname",
#                   "len_album_name", "isRemixAlbum", "isOSTAlbum", "isSingleAlbum", "album_name_is_title_name",
#                   "isBeatAlbum", "isCoverAlbum","copyright_cat" ,
#                   "composers_id_min_cat",
#                    "freq_artist_min", "freq_composer_min","dayofyear","weekday",
#                   "num_album_per_min_artist", "num_album_per_min_composer", 
#                    "numsongInAlbum","isSingleAlbum_onesong","artist_mean_id", "artist_std_id" ,"artist_count_id"]

chosen_features  += ["predicted_label"]
# chosen_features += ["mean_album_score", "mean_artist_min_score"]
df_train = df[df.dataset=="train"]
df_test = df[df.dataset=="test"]

param = {
    'bagging_freq': 20,          
    'bagging_fraction': 0.95,   'boost_from_average':'false',   
    'boost': 'gbdt',             'feature_fraction': 0.1,     'learning_rate': 0.001,
    'max_depth': -1,             'metric':'root_mean_squared_error', 'min_data_in_leaf': 5,   
       'num_leaves': 50,            
    'num_threads': 8,              'tree_learner': 'serial',   'objective': 'regression',
    'reg_alpha': 0.1002650970728192, 'reg_lambda': 0.1003427518866501,'verbosity': 1,
    "seed": 99999
}

folds = StratifiedKFold(n_splits=10, shuffle=True, random_state=99999)
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
labels= df_train.label
# fig, axes = plt.subplots(5, 1, figsize=(10, 10*5))
# axes = axes.flat
for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train.values, df_train.label.values)):
    print("Fold {}".format(fold_))
    
    # Create lookup table
    album_lookup_table = create_album_score_lookup_table(df_train.iloc[trn_idx])
    artist_lookup_table = create_artist_score_lookup_table(df_train.iloc[trn_idx])
    
#     df_train["mean_album_score"]= [assign_value_album(album_lookup_table, r) for i, r in df_train.iterrows()]
#     df_train["mean_artist_min_score"]= [assign_value_artist(artist_lookup_table, r) for i, r in df_train.iterrows()]
#     df_train["mean_album_score"] = df_train["mean_album_score"].fillna(0)
#     df_train["mean_artist_min_score"] = df_train["mean_artist_min_score"].fillna(0)
    
    
    df_train["predicted_label"] = [assign_value(album_lookup_table,artist_lookup_table, r) for i, r in df_train.iterrows()]
    
    print("Percentage null in valid:", len(np.sum(df_train.iloc[val_idx].isnull())) / len(df_train.iloc[val_idx]))
    df_train["predicted_label"] =df_train["predicted_label"].fillna(99999)
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][chosen_features], label=labels.iloc[trn_idx])
    val_data = lgb.Dataset(df_train.iloc[val_idx][chosen_features], label=labels.iloc[val_idx])
    clf = lgb.train(param, trn_data, 1000000, valid_sets = [trn_data, val_data], verbose_eval=5000, early_stopping_rounds = 20000)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][chosen_features], num_iteration=clf.best_iteration)
#     predictions += clf.predict(df_test[chosen_features], num_iteration=clf.best_iteration) / folds.n_splits
# Out:
# Fold 0
# /home/vuthede/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/vuthede/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/ipykernel_launcher.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Percentage null in valid: 0.21271929824561403
# Training until validation scores don't improve for 20000 rounds
# [5000]	training's rmse: 1.54223	valid_1's rmse: 1.8297
# [10000]	training's rmse: 1.26158	valid_1's rmse: 1.69236
# [15000]	training's rmse: 1.10634	valid_1's rmse: 1.63735
# [20000]	training's rmse: 0.998597	valid_1's rmse: 1.60751
# [25000]	training's rmse: 0.915847	valid_1's rmse: 1.58912
# [30000]	training's rmse: 0.847873	valid_1's rmse: 1.57679
# [35000]	training's rmse: 0.791161	valid_1's rmse: 1.56876
# [40000]	training's rmse: 0.742481	valid_1's rmse: 1.56298
# [45000]	training's rmse: 0.700032	valid_1's rmse: 1.55831
# [50000]	training's rmse: 0.662435	valid_1's rmse: 1.555
# [55000]	training's rmse: 0.628514	valid_1's rmse: 1.55251
# [60000]	training's rmse: 0.598072	valid_1's rmse: 1.55076
# [65000]	training's rmse: 0.570291	valid_1's rmse: 1.54923
# [70000]	training's rmse: 0.544788	valid_1's rmse: 1.54817
# [75000]	training's rmse: 0.521411	valid_1's rmse: 1.5476
# [80000]	training's rmse: 0.499501	valid_1's rmse: 1.54704
# [85000]	training's rmse: 0.47956	valid_1's rmse: 1.54653
# [90000]	training's rmse: 0.461078	valid_1's rmse: 1.5463
# [95000]	training's rmse: 0.44414	valid_1's rmse: 1.54602
# [100000]	training's rmse: 0.42795	valid_1's rmse: 1.54609
# [105000]	training's rmse: 0.412962	valid_1's rmse: 1.54653
# [110000]	training's rmse: 0.398911	valid_1's rmse: 1.54682
# [115000]	training's rmse: 0.385875	valid_1's rmse: 1.54706
# Early stopping, best iteration is:
# [96804]	training's rmse: 0.438007	valid_1's rmse: 1.54595
# Fold 1
# Percentage null in valid: 0.21271929824561403
# Training until validation scores don't improve for 20000 rounds
# [5000]	training's rmse: 1.53496	valid_1's rmse: 1.80922
# [10000]	training's rmse: 1.24958	valid_1's rmse: 1.69725
# [15000]	training's rmse: 1.0934	valid_1's rmse: 1.65929
# [20000]	training's rmse: 0.986515	valid_1's rmse: 1.64039
# [25000]	training's rmse: 0.904578	valid_1's rmse: 1.62926
# [30000]	training's rmse: 0.837365	valid_1's rmse: 1.62097
# [35000]	training's rmse: 0.781642	valid_1's rmse: 1.61478
# [40000]	training's rmse: 0.733853	valid_1's rmse: 1.61026
# [45000]	training's rmse: 0.692312	valid_1's rmse: 1.60662
# [50000]	training's rmse: 0.65546	valid_1's rmse: 1.6035
# [55000]	training's rmse: 0.622233	valid_1's rmse: 1.60093
# [60000]	training's rmse: 0.592062	valid_1's rmse: 1.59886
# [65000]	training's rmse: 0.564542	valid_1's rmse: 1.59674
# [70000]	training's rmse: 0.539797	valid_1's rmse: 1.59498
# [75000]	training's rmse: 0.516798	valid_1's rmse: 1.59335
# [80000]	training's rmse: 0.495476	valid_1's rmse: 1.59216
# [85000]	training's rmse: 0.476025	valid_1's rmse: 1.59121
# [90000]	training's rmse: 0.457732	valid_1's rmse: 1.59066
# [95000]	training's rmse: 0.441236	valid_1's rmse: 1.58985
# [100000]	training's rmse: 0.425326	valid_1's rmse: 1.58963
# [105000]	training's rmse: 0.41067	valid_1's rmse: 1.58941
# [110000]	training's rmse: 0.396927	valid_1's rmse: 1.58919
# [115000]	training's rmse: 0.384107	valid_1's rmse: 1.58895
# [120000]	training's rmse: 0.372083	valid_1's rmse: 1.58858
# [125000]	training's rmse: 0.360751	valid_1's rmse: 1.58844
# [130000]	training's rmse: 0.350273	valid_1's rmse: 1.58824
# [135000]	training's rmse: 0.34026	valid_1's rmse: 1.58813
# [140000]	training's rmse: 0.330752	valid_1's rmse: 1.58801
# [145000]	training's rmse: 0.321696	valid_1's rmse: 1.58797
# [150000]	training's rmse: 0.313083	valid_1's rmse: 1.58811
# [155000]	training's rmse: 0.304925	valid_1's rmse: 1.58827
# [160000]	training's rmse: 0.297117	valid_1's rmse: 1.5883
# Early stopping, best iteration is:
# [143946]	training's rmse: 0.323511	valid_1's rmse: 1.58792
# Fold 2
# Percentage null in valid: 0.21318681318681318
# Training until validation scores don't improve for 20000 rounds
# [5000]	training's rmse: 1.5419	valid_1's rmse: 1.80688
# [10000]	training's rmse: 1.2579	valid_1's rmse: 1.6679
# [15000]	training's rmse: 1.10164	valid_1's rmse: 1.61243
# [20000]	training's rmse: 0.993737	valid_1's rmse: 1.58293
# [25000]	training's rmse: 0.910734	valid_1's rmse: 1.56311
# [30000]	training's rmse: 0.843124	valid_1's rmse: 1.54916
# [35000]	training's rmse: 0.786838	valid_1's rmse: 1.53861
# [40000]	training's rmse: 0.738613	valid_1's rmse: 1.53084
# [45000]	training's rmse: 0.696766	valid_1's rmse: 1.52489
# [50000]	training's rmse: 0.659443	valid_1's rmse: 1.52059
# [55000]	training's rmse: 0.626133	valid_1's rmse: 1.51697
# [60000]	training's rmse: 0.5959	valid_1's rmse: 1.51412
# [65000]	training's rmse: 0.568201	valid_1's rmse: 1.51184
# [70000]	training's rmse: 0.543188	valid_1's rmse: 1.50979
# [75000]	training's rmse: 0.520061	valid_1's rmse: 1.50844
# [80000]	training's rmse: 0.498601	valid_1's rmse: 1.50715
# [85000]	training's rmse: 0.478851	valid_1's rmse: 1.50641
# [90000]	training's rmse: 0.460716	valid_1's rmse: 1.50582
# [95000]	training's rmse: 0.443932	valid_1's rmse: 1.50539
# [100000]	training's rmse: 0.428026	valid_1's rmse: 1.50511
# [105000]	training's rmse: 0.413193	valid_1's rmse: 1.505
# [110000]	training's rmse: 0.399365	valid_1's rmse: 1.50494
# [115000]	training's rmse: 0.386411	valid_1's rmse: 1.50491
# [120000]	training's rmse: 0.374195	valid_1's rmse: 1.50498
# [125000]	training's rmse: 0.362756	valid_1's rmse: 1.50513
# [130000]	training's rmse: 0.352139	valid_1's rmse: 1.50524
# [135000]	training's rmse: 0.342023	valid_1's rmse: 1.50538
# Early stopping, best iteration is:
# [117347]	training's rmse: 0.380586	valid_1's rmse: 1.5048
# Fold 3
# Percentage null in valid: 0.21342134213421343
# Training until validation scores don't improve for 20000 rounds
# [5000]	training's rmse: 1.53885	valid_1's rmse: 1.85406
# [10000]	training's rmse: 1.2567	valid_1's rmse: 1.70436
# [15000]	training's rmse: 1.10077	valid_1's rmse: 1.64726
# [20000]	training's rmse: 0.992998	valid_1's rmse: 1.61731
# [25000]	training's rmse: 0.909834	valid_1's rmse: 1.59949
# [30000]	training's rmse: 0.841956	valid_1's rmse: 1.58848
# [35000]	training's rmse: 0.785615	valid_1's rmse: 1.58145
# [40000]	training's rmse: 0.737211	valid_1's rmse: 1.5773
# [45000]	training's rmse: 0.694896	valid_1's rmse: 1.57461
# [50000]	training's rmse: 0.657324	valid_1's rmse: 1.57262
# [55000]	training's rmse: 0.623616	valid_1's rmse: 1.57147
# [60000]	training's rmse: 0.593164	valid_1's rmse: 1.57099
# [65000]	training's rmse: 0.565146	valid_1's rmse: 1.57095
# [70000]	training's rmse: 0.540015	valid_1's rmse: 1.57103
# [75000]	training's rmse: 0.516593	valid_1's rmse: 1.57108
# [80000]	training's rmse: 0.49505	valid_1's rmse: 1.57134
# Early stopping, best iteration is:
# [61508]	training's rmse: 0.584397	valid_1's rmse: 1.57078
# Fold 4
# Percentage null in valid: 0.21342134213421343
# Training until validation scores don't improve for 20000 rounds
# [5000]	training's rmse: 1.53307	valid_1's rmse: 1.87504
# [10000]	training's rmse: 1.24989	valid_1's rmse: 1.74621
# [15000]	training's rmse: 1.09471	valid_1's rmse: 1.69598
# [20000]	training's rmse: 0.988228	valid_1's rmse: 1.66873
# [25000]	training's rmse: 0.905955	valid_1's rmse: 1.65053
# [30000]	training's rmse: 0.838275	valid_1's rmse: 1.63821
# [35000]	training's rmse: 0.782079	valid_1's rmse: 1.62929
# [40000]	training's rmse: 0.73376	valid_1's rmse: 1.62231
# [45000]	training's rmse: 0.691625	valid_1's rmse: 1.6172
# [50000]	training's rmse: 0.654292	valid_1's rmse: 1.61331
# [55000]	training's rmse: 0.620973	valid_1's rmse: 1.60946
# [60000]	training's rmse: 0.590945	valid_1's rmse: 1.60687
# [65000]	training's rmse: 0.563432	valid_1's rmse: 1.60451
# [70000]	training's rmse: 0.538325	valid_1's rmse: 1.60266
# [75000]	training's rmse: 0.515183	valid_1's rmse: 1.60106
# [80000]	training's rmse: 0.49378	valid_1's rmse: 1.59983
# [85000]	training's rmse: 0.473975	valid_1's rmse: 1.59891
# [90000]	training's rmse: 0.455819	valid_1's rmse: 1.59797
# [95000]	training's rmse: 0.439191	valid_1's rmse: 1.59731
# [100000]	training's rmse: 0.423158	valid_1's rmse: 1.59683
# [105000]	training's rmse: 0.408351	valid_1's rmse: 1.59645
# [110000]	training's rmse: 0.394407	valid_1's rmse: 1.59596
# [115000]	training's rmse: 0.381585	valid_1's rmse: 1.59571
# [120000]	training's rmse: 0.369518	valid_1's rmse: 1.59525
# [125000]	training's rmse: 0.358109	valid_1's rmse: 1.59505
# [130000]	training's rmse: 0.347515	valid_1's rmse: 1.59499
# [135000]	training's rmse: 0.337497	valid_1's rmse: 1.59489
# [140000]	training's rmse: 0.328	valid_1's rmse: 1.59493
# [145000]	training's rmse: 0.318897	valid_1's rmse: 1.5949
# [150000]	training's rmse: 0.31027	valid_1's rmse: 1.595
# Early stopping, best iteration is:
# [133941]	training's rmse: 0.339584	valid_1's rmse: 1.59484
# Fold 5
# Percentage null in valid: 0.21389195148842338
# Training until validation scores don't improve for 20000 rounds
# [5000]	training's rmse: 1.53521	valid_1's rmse: 1.88446
# [10000]	training's rmse: 1.2525	valid_1's rmse: 1.7508
# [15000]	training's rmse: 1.09707	valid_1's rmse: 1.69868
# [20000]	training's rmse: 0.989881	valid_1's rmse: 1.67157
# [25000]	training's rmse: 0.906878	valid_1's rmse: 1.65324
# [30000]	training's rmse: 0.839143	valid_1's rmse: 1.64073
# [35000]	training's rmse: 0.782591	valid_1's rmse: 1.63166
# [40000]	training's rmse: 0.734187	valid_1's rmse: 1.62495
# [45000]	training's rmse: 0.692019	valid_1's rmse: 1.61987
# [50000]	training's rmse: 0.654865	valid_1's rmse: 1.61527
# [55000]	training's rmse: 0.621542	valid_1's rmse: 1.61185
# [60000]	training's rmse: 0.591235	valid_1's rmse: 1.60926
# [65000]	training's rmse: 0.563721	valid_1's rmse: 1.60704
# [70000]	training's rmse: 0.538563	valid_1's rmse: 1.605
# [75000]	training's rmse: 0.51548	valid_1's rmse: 1.60377
# [80000]	training's rmse: 0.49381	valid_1's rmse: 1.60268
# [85000]	training's rmse: 0.474361	valid_1's rmse: 1.60167
# [90000]	training's rmse: 0.456156	valid_1's rmse: 1.60091
# [95000]	training's rmse: 0.439355	valid_1's rmse: 1.60027
# [100000]	training's rmse: 0.423467	valid_1's rmse: 1.59975
# [105000]	training's rmse: 0.408562	valid_1's rmse: 1.59916
# [110000]	training's rmse: 0.394549	valid_1's rmse: 1.59878
# [115000]	training's rmse: 0.381583	valid_1's rmse: 1.59855
# [120000]	training's rmse: 0.369528	valid_1's rmse: 1.59837
# [125000]	training's rmse: 0.357985	valid_1's rmse: 1.59823
# [130000]	training's rmse: 0.347191	valid_1's rmse: 1.59812
# [135000]	training's rmse: 0.336938	valid_1's rmse: 1.59798
# [140000]	training's rmse: 0.327261	valid_1's rmse: 1.59781
# [145000]	training's rmse: 0.318025	valid_1's rmse: 1.59785
# [150000]	training's rmse: 0.309141	valid_1's rmse: 1.59777
# [155000]	training's rmse: 0.300752	valid_1's rmse: 1.59764
# [160000]	training's rmse: 0.292659	valid_1's rmse: 1.59767
# [165000]	training's rmse: 0.285134	valid_1's rmse: 1.59773
# [170000]	training's rmse: 0.277983	valid_1's rmse: 1.59783
# [175000]	training's rmse: 0.271368	valid_1's rmse: 1.5979
# Early stopping, best iteration is:
# [158380]	training's rmse: 0.295279	valid_1's rmse: 1.5976
# Fold 6
# Percentage null in valid: 0.2143646408839779
# Training until validation scores don't improve for 20000 rounds
# [5000]	training's rmse: 1.54038	valid_1's rmse: 1.84326
# [10000]	training's rmse: 1.2579	valid_1's rmse: 1.70802
# [15000]	training's rmse: 1.10197	valid_1's rmse: 1.65547
# [20000]	training's rmse: 0.993745	valid_1's rmse: 1.62751
# [25000]	training's rmse: 0.910363	valid_1's rmse: 1.6098
# [30000]	training's rmse: 0.841646	valid_1's rmse: 1.59783
# [35000]	training's rmse: 0.784721	valid_1's rmse: 1.59015
# [40000]	training's rmse: 0.735827	valid_1's rmse: 1.58426
# [45000]	training's rmse: 0.69352	valid_1's rmse: 1.58027
# [50000]	training's rmse: 0.655631	valid_1's rmse: 1.57725
# [55000]	training's rmse: 0.62196	valid_1's rmse: 1.57487
# [60000]	training's rmse: 0.591444	valid_1's rmse: 1.57317
# [65000]	training's rmse: 0.56339	valid_1's rmse: 1.57175
# [70000]	training's rmse: 0.53813	valid_1's rmse: 1.5712
# [75000]	training's rmse: 0.51463	valid_1's rmse: 1.57049
# [80000]	training's rmse: 0.493056	valid_1's rmse: 1.57036
# [85000]	training's rmse: 0.473133	valid_1's rmse: 1.56997
# [90000]	training's rmse: 0.454569	valid_1's rmse: 1.56992
# [95000]	training's rmse: 0.437552	valid_1's rmse: 1.57
# [100000]	training's rmse: 0.421231	valid_1's rmse: 1.57022
# [105000]	training's rmse: 0.406067	valid_1's rmse: 1.57027
# Early stopping, best iteration is:
# [88310]	training's rmse: 0.460484	valid_1's rmse: 1.5698
# Fold 7
# Percentage null in valid: 0.2143646408839779
# Training until validation scores don't improve for 20000 rounds
# [5000]	training's rmse: 1.53245	valid_1's rmse: 1.87026
# [10000]	training's rmse: 1.25125	valid_1's rmse: 1.73582
# [15000]	training's rmse: 1.09676	valid_1's rmse: 1.68141
# [20000]	training's rmse: 0.989518	valid_1's rmse: 1.65099
# [25000]	training's rmse: 0.906383	valid_1's rmse: 1.63223
# [30000]	training's rmse: 0.838178	valid_1's rmse: 1.61895
# [35000]	training's rmse: 0.781205	valid_1's rmse: 1.60984
# [40000]	training's rmse: 0.732419	valid_1's rmse: 1.60299
# [45000]	training's rmse: 0.68988	valid_1's rmse: 1.59794
# [50000]	training's rmse: 0.651881	valid_1's rmse: 1.59452
# [55000]	training's rmse: 0.618025	valid_1's rmse: 1.59172
# [60000]	training's rmse: 0.586935	valid_1's rmse: 1.5899
# [65000]	training's rmse: 0.558568	valid_1's rmse: 1.58806
# [70000]	training's rmse: 0.533059	valid_1's rmse: 1.58686
# [75000]	training's rmse: 0.509313	valid_1's rmse: 1.58588
# [80000]	training's rmse: 0.48726	valid_1's rmse: 1.58546
# [85000]	training's rmse: 0.467274	valid_1's rmse: 1.58515
# [90000]	training's rmse: 0.448649	valid_1's rmse: 1.58512
# [95000]	training's rmse: 0.431519	valid_1's rmse: 1.58503
# [100000]	training's rmse: 0.415242	valid_1's rmse: 1.58524
# [105000]	training's rmse: 0.399946	valid_1's rmse: 1.58551
# [110000]	training's rmse: 0.38584	valid_1's rmse: 1.58581
# Early stopping, best iteration is:
# [92110]	training's rmse: 0.441407	valid_1's rmse: 1.58495
# Fold 8
# Percentage null in valid: 0.2143646408839779
# Training until validation scores don't improve for 20000 rounds
# [5000]	training's rmse: 1.53413	valid_1's rmse: 1.84045
# [10000]	training's rmse: 1.24796	valid_1's rmse: 1.71588
# [15000]	training's rmse: 1.0918	valid_1's rmse: 1.66929
# [20000]	training's rmse: 0.984856	valid_1's rmse: 1.64586
# [25000]	training's rmse: 0.90237	valid_1's rmse: 1.63088
# [30000]	training's rmse: 0.834705	valid_1's rmse: 1.62059
# [35000]	training's rmse: 0.778784	valid_1's rmse: 1.6133
# [40000]	training's rmse: 0.73087	valid_1's rmse: 1.60848
# [45000]	training's rmse: 0.688893	valid_1's rmse: 1.60417
# [50000]	training's rmse: 0.651724	valid_1's rmse: 1.6013
# [55000]	training's rmse: 0.618518	valid_1's rmse: 1.59919
# [60000]	training's rmse: 0.588413	valid_1's rmse: 1.59758
# [65000]	training's rmse: 0.56093	valid_1's rmse: 1.59598
# [70000]	training's rmse: 0.535972	valid_1's rmse: 1.59532
# [75000]	training's rmse: 0.513051	valid_1's rmse: 1.59492
# [80000]	training's rmse: 0.491449	valid_1's rmse: 1.59434
# [85000]	training's rmse: 0.471948	valid_1's rmse: 1.5942
# [90000]	training's rmse: 0.453798	valid_1's rmse: 1.59413
# [95000]	training's rmse: 0.437104	valid_1's rmse: 1.59422
# [100000]	training's rmse: 0.421108	valid_1's rmse: 1.59445
# [105000]	training's rmse: 0.406206	valid_1's rmse: 1.59504
# [110000]	training's rmse: 0.392306	valid_1's rmse: 1.5955
# Early stopping, best iteration is:
# [90697]	training's rmse: 0.451401	valid_1's rmse: 1.59405

# %%
from math import sqrt

print("RMSE: {:<8.5f}".format(sqrt(mean_squared_error(df_train.label, oof))))
sub = pd.DataFrame({"ID": df_test.ID.values})
sub["label"] = predictions
sub.to_csv("submission_lightgbm.csv", index=False, header=False)
# Out:
# RMSE: 6.22130

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(30,30))
lgb.plot_importance(clf, max_num_features=20,importance_type='gain')

# %%
# chosen_features = ["album_right","freq_artist",  "day", 
#                      "isBeat",  "num_song_release_in_final_month",
#                   "length","album_artist",
#                   "artist_name_cat","composers_name_cat",
#                   "artist_id_min_cat", "composers_id_min_cat",  "artist_id_max_cat", "composers_id_max_cat", 
#                    "freq_artist_min","dayofyear", 
#                    "numsongInAlbum","artist_mean_id","artist_std_id" ,"artist_count_id" ]
# Out:
# 19
